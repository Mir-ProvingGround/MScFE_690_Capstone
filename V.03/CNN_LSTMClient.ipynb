# %%
#Waiting for prediction order
import socket

# Create a socket object
server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# Get local machine name
host = socket.gethostname()
port = 9999
msg='none'
# Bind to the port
server_socket.bind((host, port))

server_socket.listen(5)
print("Standby for prediction order")
while True:
    # Establish a connection
    client_socket, addr = server_socket.accept()
    print("Receive prediction order")
    # Receive no more than 1024 bytes
    msg = (client_socket.recv(1024)).decode('utf-8')
    client_socket.close()
    break

if(msg=='MSFT'):
    #Time recording
    import datetime
    startCNNs_LSTMs = datetime.datetime.now()

    #Library list
    # Library imports
    import keras
    from sklearn.metrics import mean_squared_error
    from keras.models import Model, Sequential
    from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, LeakyReLU, LSTM, Input, Activation
    from keras import optimizers, regularizers
    import numpy as np
    import pandas as pd
    import tensorflow as tf
    import yfinance as yf
    from sklearn import preprocessing
    import matplotlib.pyplot as plt
    from keras.callbacks import EarlyStopping, ReduceLROnPlateau
    import ta
    #Set random parameter
    np.random.seed(4)
    tf.random.set_seed(4)

    # Get the data for the stock MSFT between '2012-02-01' to '2019-03-05'
    df = yf.download('MSFT','2012-02-01','2019-03-05')
    # Heiken Ashi calculation
    heiken_ashi_df = df.copy()
    heiken_ashi_df['HA_Close'] = (df['Open'] + df['High'] + df['Low'] + df['Close']) / 4
    heiken_ashi_df['HA_Open'] = (df['Open'] + df['Close']) / 2
    heiken_ashi_df['HA_High'] = df[['Open', 'Close', 'High']].max(axis=1)
    heiken_ashi_df['HA_Low'] = df[['Open', 'Close', 'Low']].min(axis=1)

    # Additional technical indicators
    df['RSI'] = ta.momentum.rsi(df['Close'], window=14)
    df['MACD'] = ta.trend.macd_diff(df['Close'])
    df['MA_10'] = df['Close'].rolling(window=10).mean()

    # Combine all features into one DataFrame
    df = df.join(heiken_ashi_df[['HA_Open', 'HA_High', 'HA_Low', 'HA_Close']])
    df.dropna(inplace=True)

    next_day_closed = df['Close'].shift(-1, axis=0)
    next_day_closed.drop(index=next_day_closed.index[len(next_day_closed)-1], axis=0, inplace=True)
    df.drop(index=df.index[len(df)-1], axis=0, inplace=True)
    date = df.index
    df.reset_index(drop=True, inplace=True)
    df.tail()
    open_values=df['Open'].to_numpy()
    closed_values=df['Close'].to_numpy()
    date_values=date.to_numpy()



    #convert as an array will be used as feature in classifier
    data = df.to_numpy()
    #convert next closed data to array, will be used as label
    next_day_closed_values=next_day_closed.to_numpy()
    # dataset split and number of rows (history) involved in prediction
    test_split = 0.5
    history_points=100

    #normalized data
    data_normaliser = preprocessing.MinMaxScaler()
    #data=data.reshape(-1, 1)
    data_normalised = data_normaliser.fit_transform(data)
    next_day_closed_values = next_day_closed_values.reshape(-1, 1)
    next_day_closed_values_normalised = data_normaliser.fit_transform(next_day_closed_values)

    data_histories_normalised = np.array([data_normalised[i:i + history_points].copy() for i in range(len(data_normalised) - history_points)])
    n = 1558#int(data_histories_normalised.shape[0] * test_split)
    next_day_closed_values_normalised = np.array([next_day_closed_values_normalised[i + history_points].copy() for i in range(len(next_day_closed_values_normalised) - history_points)])
    next_day_closed_values = np.array([next_day_closed_values[i + history_points].copy() for i in range(len(next_day_closed_values) - history_points)])
    open_values = np.array([open_values[i + history_points].copy() for i in range(len(open_values) - history_points)])
    closed_values= np.array([closed_values[i + history_points].copy() for i in range(len(closed_values) - history_points)])
    date_values= np.array([date_values[i + history_points].copy() for i in range(len(date_values) - history_points)])

    # Generate 12x1 images from the rolling windows
    def create_images(data):
        images = []
        for i in range(len(data)):
            window = data[i]
            image = window.T
            #print(image.shape)
            if image.shape == (13, 100):
                images.append(image)
        return np.array(images)
    #

    images = create_images(data_histories_normalised)
    #print(len(images))
    #TRAIN DATA
    data_train = images[:n]#data_histories_normalised[:n]
    y_train = next_day_closed_values_normalised[:n]

    #TEST DATA
    data_test = images[n:]#data_histories_normalised[n:]
    y_test = next_day_closed_values_normalised[n:]
    #print(len(y_test))
    #print(len(data_test))
    # Reshape for CNN
    data_train = data_train.reshape(-1, 13, 1, 1)
    data_test = data_test.reshape(-1, 13, 1, 1)

    unscaled_y_test = next_day_closed_values[n:]
    unscaled_y=next_day_closed_values
    stacking = pd.DataFrame(columns=['date_time','open', 'close','delta_next_day', 'nextclose'])
    stacking['date_time'] = date_values
    stacking['open'] = open_values
    stacking['close'] = closed_values
    stacking['nextclose'] = next_day_closed


    lr=0.0001
    #CNN MODEL
    mse_=0
    nb_prediction=50
    for ii in range(0,nb_prediction,2):
        # Define CNN model
        model = Sequential()
        model.add(Conv2D(64, kernel_size=(3, 3), padding='same', input_shape=(100, 13, 1), kernel_regularizer=regularizers.l2(0.01)))
        model.add(BatchNormalization())
        #model.add(LeakyReLU(negative_slope=0.1))  # Use negative_slope instead of alpha
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))
        model.add(Conv2D(128, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
        model.add(BatchNormalization())
        #model.add(LeakyReLU(negative_slope=0.1))  # Use negative_slope instead of alpha
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.3))
        model.add(Conv2D(256, kernel_size=(2, 2), padding='same', kernel_regularizer=regularizers.l2(0.01)))
        model.add(BatchNormalization())
        #model.add(LeakyReLU(negative_slope=0.1))  # Use negative_slope instead of alpha
        model.add(Flatten())
        model.add(Dense(512, activation='relu'))
        model.add(Dropout(0.35))
        model.add(Dense(1, activation='linear'))

        # Compile the model
        nadam = optimizers.Nadam(learning_rate=ii*lr+lr)
        model.compile(optimizer=nadam, loss='mse')

        # Add early stopping and learning rate scheduler
        early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
        #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

        # Train the model
        data_train=tf.reshape(data_train,(1558,100,13,1))
        model.fit(data_train, y_train, batch_size=64, epochs=25)

        # Test the model
        data_test=tf.reshape(data_test,(90,100,13,1))
        images=tf.reshape(images,(1648,100,13,1))
        # evaluation
        y_test_predicted = model.predict(data_test)
        y_test_predicted = data_normaliser.inverse_transform(y_test_predicted)
        y_predicted = model.predict(images)#data_histories_normalised)
        y_predicted = data_normaliser.inverse_transform(y_predicted)
        unscaled_y_test = np.reshape(unscaled_y_test, (-1, 1))
     #   print(unscaled_y_test.shape)
     #   print(y_test_predicted.shape)

        assert unscaled_y_test.shape == y_test_predicted.shape
        #real_mse = np.mean(np.square(unscaled_y_test - y_test_predicted))
        #mse=real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
        #scaled_mse = scaled_mse+real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
        print("Prediction: ",ii)
        #print('MSE:',tf.keras.losses.MSE(tf.expand_dims(srcTF, axis=-1) , tf.expand_dims(tgtTF, axis=-1)) )

        plt.gcf().set_size_inches(22, 15, forward=True)
        start = 0
        end = -1
        #real = plt.plot(unscaled_y_test[start:end], label='real')
        #pred = plt.plot(y_test_predicted[start:end], label='predicted')
        #real = plt.plot(unscaled_y[start:end], label='real')
        #pred = plt.plot(y_predicted[start:end], label='predicted')
        #plt.legend(['Real', 'Predicted'])
        #plt.show()
        #from datetime import datetime
        #model.save(f'basic_model.h5')

        #If next_day_closed_price is higher than today closed price for given threshold, then long or buy
        #If the difference is negative, short or sell, otherwise hold.
        thresh = 0.1
        hold_=0
        long_=1
        short_=2
        strategy=[]
        closed_price_today=[]
        for i in range (len(unscaled_y)):
            closed_price_today_=unscaled_y[i]
            closed_price_today.append(closed_price_today_)
            predicted_closed_price_tomorrow = y_predicted[i]
            delta=predicted_closed_price_tomorrow-closed_price_today_
            if delta > thresh:
                strategy.append(long_)
            elif delta < 0:
                strategy.append(short_)
            else:
                strategy.append(hold_)
        mse=mean_squared_error(next_day_closed_values, y_predicted)
        mse_=mse_+mse
        pt = datetime.datetime.now()-startCNNs_LSTMs
        total_seconds = pt.total_seconds()
        print('Step 1. Number_of_prediction: ',(ii+1),' Average_MSE: ',mse_/(ii+1),' Execution_time (s): ',total_seconds," Learning_rate:", ii*lr+lr)
        S='prediction_'+str(ii)
        stacking[S] = strategy

    #stacking['delta_next_day'] = next_day_closed_values-y_predicted
    #stacking['nextclose']=y_predicted#stacking.drop['nextclose'], axis=1, inplace=True)
    #stacking.to_csv('LSTM_CNNs.csv')


    #start with LSTM

    #convert as an array will be used as feature in classifier
    data = df.to_numpy()
    #convert next closed data to array, will be used as label
    next_day_closed_values=next_day_closed.to_numpy()
    # dataset split and number of rows (history) involved in prediction
    test_split = 0.5
    history_points=100

    #normalized data
    data_normaliser = preprocessing.MinMaxScaler()
    #data=data.reshape(-1, 1)
    data_normalised = data_normaliser.fit_transform(data)
    next_day_closed_values = next_day_closed_values.reshape(-1, 1)
    next_day_closed_values_normalised = data_normaliser.fit_transform(next_day_closed_values)

    data_histories_normalised = np.array([data_normalised[i:i + history_points].copy() for i in range(len(data_normalised) - history_points)])
    n = 1558#int(data_histories_normalised.shape[0] * test_split)
    next_day_closed_values_normalised = np.array([next_day_closed_values_normalised[i + history_points].copy() for i in range(len(next_day_closed_values_normalised) - history_points)])
    next_day_closed_values = np.array([next_day_closed_values[i + history_points].copy() for i in range(len(next_day_closed_values) - history_points)])
    open_values = np.array([open_values[i + history_points].copy() for i in range(len(open_values) - history_points)])
    closed_values= np.array([closed_values[i + history_points].copy() for i in range(len(closed_values) - history_points)])
    date_values= np.array([date_values[i + history_points].copy() for i in range(len(date_values) - history_points)])

    #TRAIN DATA
    data_train = data_histories_normalised[:n]
    y_train = next_day_closed_values_normalised[:n]

    #TEST DATA
    data_test = data_histories_normalised[n:]
    y_test = next_day_closed_values_normalised[n:]

    unscaled_y_test = next_day_closed_values[n:]
    unscaled_y=next_day_closed_values
    #stacking = pd.DataFrame(columns=['date_time','open', 'close','delta_next_day', 'nextclose'])
    #stacking['date_time'] = date_values
    #stacking['open'] = open_values
    #stacking['close'] = closed_values
    #stacking['nextclose'] = next_day_closed


    for ii in range(1,nb_prediction,2):
        # model architecture
        lstm_input = Input(shape=(history_points, 13), name='lstm_input')
        x = LSTM(50, name='lstm_0')(lstm_input)
        x = Dropout(0.2, name='lstm_dropout_0')(x)
        x = Dense(64, name='dense_0')(x)
        x = Activation('sigmoid', name='sigmoid_0')(x)
        x = Dense(1, name='dense_1')(x)
        output = Activation('linear', name='linear_output')(x)

        model = Model(inputs=lstm_input, outputs=output)
        adam = optimizers.Adam(learning_rate=ii*lr+lr)
        model.compile(optimizer=adam, loss='mse')
        #print(len(data_train))
        #print(len(y_train))

        model.fit(x=data_train, y=y_train, batch_size=32, epochs=25, shuffle=True, validation_split=0.1)

        # evaluation
        y_test_predicted = model.predict(data_test)
        y_test_predicted = data_normaliser.inverse_transform(y_test_predicted)
        y_predicted = model.predict(data_histories_normalised)
        y_predicted = data_normaliser.inverse_transform(y_predicted)
        unscaled_y_test = np.reshape(unscaled_y_test, (-1, 1))
        #   print(unscaled_y_test.shape)
     #   print(y_test_predicted.shape)

        assert unscaled_y_test.shape == y_test_predicted.shape
        #real_mse = np.mean(np.square(unscaled_y_test - y_test_predicted))
        #mse=real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
        #scaled_mse = scaled_mse+real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
        #print("Prediction: ",ii)
        #print('MSE:',tf.keras.losses.MSE(tf.expand_dims(srcTF, axis=-1) , tf.expand_dims(tgtTF, axis=-1)) )

        plt.gcf().set_size_inches(22, 15, forward=True)
        start = 0
        end = -1
        #real = plt.plot(unscaled_y_test[start:end], label='real')
        #pred = plt.plot(y_test_predicted[start:end], label='predicted')
        #real = plt.plot(unscaled_y[start:end], label='real')
        #pred = plt.plot(y_predicted[start:end], label='predicted')
        #plt.legend(['Real', 'Predicted'])
        #plt.show()
        #from datetime import datetime
        #model.save(f'basic_model.h5')

        #If next_day_closed_price is higher than today closed price for given threshold, then long or buy
        #If the difference is negative, short or sell, otherwise hold.
        thresh = 0.1
        hold_=0
        long_=1
        short_=2
        strategy=[]
        closed_price_today=[]
        for i in range (len(unscaled_y)):
            closed_price_today_=unscaled_y[i]
            closed_price_today.append(closed_price_today_)
            predicted_closed_price_tomorrow = y_predicted[i]
            delta=predicted_closed_price_tomorrow-closed_price_today_
            if delta > thresh:
                strategy.append(long_)
            elif delta < 0:
                strategy.append(short_)
            else:
                strategy.append(hold_)
        mse=mean_squared_error(next_day_closed_values, y_predicted)
        mse_=mse_+mse
        pt = datetime.datetime.now()-startCNNs_LSTMs
        total_seconds = pt.total_seconds()
        print('Step 1. Number_of_prediction: ',(ii+1),' Average_MSE: ',mse_/(ii+1),' Execution_time (s): ',total_seconds," Learning_rate:", ii*lr+lr)
        S='prediction_'+str(ii)
        stacking[S] = strategy
        print(datetime.datetime.now()-startCNNs_LSTMs)

    stacking['delta_next_day'] = next_day_closed_values-y_predicted
    stacking['nextclose']=y_predicted#stacking.drop['nextclose'], axis=1, inplace=True)
    stacking.to_csv('CNNs_LSTMs.csv')

    today = plt.plot(next_day_closed_values, label='Tomorrow')
    tomorrow = plt.plot(y_predicted, label='Tomorrow_Predicted')
    plt.legend(['Tomorrow', 'Tomorrow_Predicted_CNNs_LSTMs'])

    plt.show()

    
# Create a socket object
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
host = socket.gethostname()  # Get local machine name
port = 12345  # Reserve a port for your service

client_socket.connect((host, port))

with open('distCNNs_LSTMs.csv', 'rb') as f:
    print("Sending file...")
    while True:
        data = f.read(1024)
        if not data:
            break
        client_socket.send(data)
    print("File sent successfully")

client_socket.close()
# Out:
# Standby for prediction order
# Receive prediction order
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\anaconda3\lib\site-packages\yfinance\utils.py:681: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# Stacking stage:
# Epoch 1/25
# 44/44 [==============================] - 8s 88ms/step - loss: 0.0433 - val_loss: 0.2605
# Epoch 2/25
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0167 - val_loss: 0.1289
# Epoch 3/25
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0086 - val_loss: 0.0598
# Epoch 4/25
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0027 - val_loss: 0.0244
# Epoch 5/25
# 44/44 [==============================] - 3s 60ms/step - loss: 0.0014 - val_loss: 0.0191
# Epoch 6/25
# 44/44 [==============================] - 3s 63ms/step - loss: 0.0013 - val_loss: 0.0148
# Epoch 7/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0012 - val_loss: 0.0155
# Epoch 8/25
# 44/44 [==============================] - 3s 60ms/step - loss: 0.0012 - val_loss: 0.0108
# Epoch 9/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0012 - val_loss: 0.0100
# Epoch 10/25
# 44/44 [==============================] - 3s 60ms/step - loss: 0.0011 - val_loss: 0.0107
# Epoch 11/25
# 44/44 [==============================] - 3s 62ms/step - loss: 9.7199e-04 - val_loss: 0.0086
# Epoch 12/25
# 44/44 [==============================] - 3s 60ms/step - loss: 0.0010 - val_loss: 0.0072
# Epoch 13/25
# 44/44 [==============================] - 3s 60ms/step - loss: 9.8821e-04 - val_loss: 0.0070
# Epoch 14/25
# 44/44 [==============================] - 3s 60ms/step - loss: 9.3145e-04 - val_loss: 0.0064
# Epoch 15/25
# 44/44 [==============================] - 3s 73ms/step - loss: 8.7766e-04 - val_loss: 0.0052
# Epoch 16/25
# 44/44 [==============================] - 3s 75ms/step - loss: 8.4073e-04 - val_loss: 0.0060
# Epoch 17/25
# 44/44 [==============================] - 3s 71ms/step - loss: 8.1963e-04 - val_loss: 0.0045
# Epoch 18/25
# 44/44 [==============================] - 3s 61ms/step - loss: 8.8733e-04 - val_loss: 0.0044
# Epoch 19/25
# 44/44 [==============================] - 3s 59ms/step - loss: 8.1324e-04 - val_loss: 0.0033
# Epoch 20/25
# 44/44 [==============================] - 3s 58ms/step - loss: 8.4130e-04 - val_loss: 0.0040
# Epoch 21/25
# 44/44 [==============================] - 3s 59ms/step - loss: 7.6398e-04 - val_loss: 0.0050
# Epoch 22/25
# 44/44 [==============================] - 3s 61ms/step - loss: 7.0991e-04 - val_loss: 0.0025
# Epoch 23/25
# 44/44 [==============================] - 3s 60ms/step - loss: 7.3161e-04 - val_loss: 0.0055
# Epoch 24/25
# 44/44 [==============================] - 2s 55ms/step - loss: 7.4383e-04 - val_loss: 0.0027
# Epoch 25/25
# 44/44 [==============================] - 2s 56ms/step - loss: 6.9695e-04 - val_loss: 0.0050
# 4/4 [==============================] - 1s 18ms/step
# 53/53 [==============================] - 1s 19ms/step
# Prediction:  0
# Step 1. Number_of_prediction:  1  Average_MSE:  11.302643923136568  Execution_time (s):  75.971406  Learning_rate: 0.0001
# 0:01:15.976923
# Epoch 1/25
# 44/44 [==============================] - 9s 87ms/step - loss: 0.0481 - val_loss: 0.2298
# Epoch 2/25
# 44/44 [==============================] - 2s 55ms/step - loss: 0.0094 - val_loss: 0.0109
# Epoch 3/25
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0011 - val_loss: 0.0089
# Epoch 4/25
# 44/44 [==============================] - 2s 53ms/step - loss: 9.5570e-04 - val_loss: 0.0060
# Epoch 5/25
# 44/44 [==============================] - 2s 53ms/step - loss: 8.6922e-04 - val_loss: 0.0047
# Epoch 6/25
# 44/44 [==============================] - 2s 52ms/step - loss: 8.6035e-04 - val_loss: 0.0051
# Epoch 7/25
# 44/44 [==============================] - 2s 52ms/step - loss: 7.6305e-04 - val_loss: 0.0046
# Epoch 8/25
# 44/44 [==============================] - 2s 52ms/step - loss: 7.5995e-04 - val_loss: 0.0031
# Epoch 9/25
# 44/44 [==============================] - 2s 51ms/step - loss: 7.0302e-04 - val_loss: 0.0041
# Epoch 10/25
# 44/44 [==============================] - 2s 52ms/step - loss: 6.7593e-04 - val_loss: 0.0016
# Epoch 11/25
# 44/44 [==============================] - 2s 52ms/step - loss: 6.1517e-04 - val_loss: 0.0032
# Epoch 12/25
# 44/44 [==============================] - 2s 52ms/step - loss: 5.9638e-04 - val_loss: 0.0039
# Epoch 13/25
# 44/44 [==============================] - 2s 52ms/step - loss: 5.9084e-04 - val_loss: 0.0021
# Epoch 14/25
# 44/44 [==============================] - 2s 52ms/step - loss: 5.8458e-04 - val_loss: 0.0014
# Epoch 15/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.0804e-04 - val_loss: 0.0013
# Epoch 16/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.9058e-04 - val_loss: 8.4947e-04
# Epoch 17/25
# 44/44 [==============================] - 2s 51ms/step - loss: 5.5229e-04 - val_loss: 0.0023
# Epoch 18/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.5911e-04 - val_loss: 0.0011
# Epoch 19/25
# 44/44 [==============================] - 2s 52ms/step - loss: 5.4913e-04 - val_loss: 7.1458e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.8219e-04 - val_loss: 8.0896e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 51ms/step - loss: 5.2373e-04 - val_loss: 0.0012
# Epoch 22/25
# 44/44 [==============================] - 2s 52ms/step - loss: 4.9427e-04 - val_loss: 7.1590e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.1349e-04 - val_loss: 8.4840e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.7145e-04 - val_loss: 0.0014
# Epoch 25/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.9028e-04 - val_loss: 0.0013
# 4/4 [==============================] - 1s 22ms/step
# 53/53 [==============================] - 1s 19ms/step
# Prediction:  2
# Step 1. Number_of_prediction:  3  Average_MSE:  5.056282458549679  Execution_time (s):  143.328089  Learning_rate: 0.00030000000000000003
# 0:02:23.328841
# Epoch 1/25
# 44/44 [==============================] - 10s 106ms/step - loss: 0.1484 - val_loss: 0.0542
# Epoch 2/25
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0029 - val_loss: 0.0302
# Epoch 3/25
# 44/44 [==============================] - 2s 55ms/step - loss: 0.0014 - val_loss: 0.0136
# Epoch 4/25
# 44/44 [==============================] - 2s 55ms/step - loss: 0.0013 - val_loss: 0.0058
# Epoch 5/25
# 44/44 [==============================] - 2s 55ms/step - loss: 0.0011 - val_loss: 0.0036
# Epoch 6/25
# 44/44 [==============================] - 2s 54ms/step - loss: 0.0010 - val_loss: 0.0028
# Epoch 7/25
# 44/44 [==============================] - 2s 55ms/step - loss: 9.4277e-04 - val_loss: 0.0032
# Epoch 8/25
# 44/44 [==============================] - 2s 54ms/step - loss: 9.4938e-04 - val_loss: 0.0021
# Epoch 9/25
# 44/44 [==============================] - 2s 55ms/step - loss: 8.7311e-04 - val_loss: 0.0030
# Epoch 10/25
# 44/44 [==============================] - 2s 55ms/step - loss: 9.1791e-04 - val_loss: 0.0017
# Epoch 11/25
# 44/44 [==============================] - 2s 55ms/step - loss: 7.8117e-04 - val_loss: 0.0020
# Epoch 12/25
# 44/44 [==============================] - 2s 56ms/step - loss: 7.3576e-04 - val_loss: 0.0034
# Epoch 13/25
# 44/44 [==============================] - 2s 54ms/step - loss: 6.9162e-04 - val_loss: 0.0015
# Epoch 14/25
# 44/44 [==============================] - 2s 56ms/step - loss: 7.8393e-04 - val_loss: 0.0013
# Epoch 15/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.2693e-04 - val_loss: 0.0017
# Epoch 16/25
# 44/44 [==============================] - 3s 60ms/step - loss: 7.0393e-04 - val_loss: 0.0014
# Epoch 17/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.6397e-04 - val_loss: 0.0017
# Epoch 18/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.9113e-04 - val_loss: 0.0018
# Epoch 19/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.8129e-04 - val_loss: 8.2047e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 54ms/step - loss: 6.9836e-04 - val_loss: 8.4462e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.0220e-04 - val_loss: 0.0011
# Epoch 22/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.3518e-04 - val_loss: 0.0015
# Epoch 23/25
# 44/44 [==============================] - 2s 53ms/step - loss: 6.6964e-04 - val_loss: 0.0016
# Epoch 24/25
# 44/44 [==============================] - 2s 50ms/step - loss: 5.9813e-04 - val_loss: 0.0016
# Epoch 25/25
# 44/44 [==============================] - 2s 47ms/step - loss: 5.6747e-04 - val_loss: 0.0016
# 4/4 [==============================] - 1s 17ms/step
# 53/53 [==============================] - 1s 17ms/step
# Prediction:  4
# Step 1. Number_of_prediction:  5  Average_MSE:  3.8986734743729934  Execution_time (s):  213.472836  Learning_rate: 0.0005
# 0:03:33.472836
# Epoch 1/25
# 44/44 [==============================] - 8s 82ms/step - loss: 0.0854 - val_loss: 0.0924
# Epoch 2/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0032 - val_loss: 0.0148
# Epoch 3/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0011 - val_loss: 0.0083
# Epoch 4/25
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0010 - val_loss: 0.0064
# Epoch 5/25
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 6/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0010 - val_loss: 0.0028
# Epoch 7/25
# 44/44 [==============================] - 2s 54ms/step - loss: 8.2095e-04 - val_loss: 0.0032
# Epoch 8/25
# 44/44 [==============================] - 2s 54ms/step - loss: 8.9969e-04 - val_loss: 0.0026
# Epoch 9/25
# 44/44 [==============================] - 2s 54ms/step - loss: 7.6939e-04 - val_loss: 0.0035
# Epoch 10/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.9048e-04 - val_loss: 0.0014
# Epoch 11/25
# 44/44 [==============================] - 2s 52ms/step - loss: 6.7232e-04 - val_loss: 0.0028
# Epoch 12/25
# 44/44 [==============================] - 2s 53ms/step - loss: 6.6171e-04 - val_loss: 0.0032
# Epoch 13/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.2649e-04 - val_loss: 0.0021
# Epoch 14/25
# 44/44 [==============================] - 2s 52ms/step - loss: 6.6563e-04 - val_loss: 9.0031e-04
# Epoch 15/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.4951e-04 - val_loss: 8.4433e-04
# Epoch 16/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.5071e-04 - val_loss: 0.0016
# Epoch 17/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.9429e-04 - val_loss: 0.0018
# Epoch 18/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.2977e-04 - val_loss: 0.0019
# Epoch 19/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.7096e-04 - val_loss: 6.9238e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.6537e-04 - val_loss: 8.7505e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.9415e-04 - val_loss: 9.2728e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.9055e-04 - val_loss: 6.9301e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.2261e-04 - val_loss: 0.0012
# Epoch 24/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.7050e-04 - val_loss: 9.3911e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 52ms/step - loss: 4.7108e-04 - val_loss: 0.0014
# 4/4 [==============================] - 1s 19ms/step
# 53/53 [==============================] - 1s 18ms/step
# Prediction:  6
# Step 1. Number_of_prediction:  7  Average_MSE:  3.337336868414336  Execution_time (s):  281.502343  Learning_rate: 0.0007000000000000001
# 0:04:41.502343
# Epoch 1/25
# 44/44 [==============================] - 8s 90ms/step - loss: 0.0078 - val_loss: 0.0099
# Epoch 2/25
# 44/44 [==============================] - 2s 55ms/step - loss: 0.0012 - val_loss: 0.0093
# Epoch 3/25
# 44/44 [==============================] - 2s 56ms/step - loss: 8.8479e-04 - val_loss: 0.0048
# Epoch 4/25
# 44/44 [==============================] - 3s 57ms/step - loss: 7.7593e-04 - val_loss: 0.0031
# Epoch 5/25
# 44/44 [==============================] - 3s 58ms/step - loss: 6.8257e-04 - val_loss: 0.0011
# Epoch 6/25
# 44/44 [==============================] - 2s 57ms/step - loss: 6.3244e-04 - val_loss: 0.0017
# Epoch 7/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.7664e-04 - val_loss: 0.0054
# Epoch 8/25
# 44/44 [==============================] - 3s 58ms/step - loss: 6.1000e-04 - val_loss: 8.1069e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.4093e-04 - val_loss: 0.0012
# Epoch 10/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.8823e-04 - val_loss: 6.7020e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.4807e-04 - val_loss: 8.9718e-04
# Epoch 12/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.6340e-04 - val_loss: 0.0026
# Epoch 13/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.6729e-04 - val_loss: 6.3375e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.6898e-04 - val_loss: 8.5266e-04
# Epoch 15/25
# 44/44 [==============================] - 2s 52ms/step - loss: 3.9128e-04 - val_loss: 7.0832e-04
# Epoch 16/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.2416e-04 - val_loss: 0.0011
# Epoch 17/25
# 44/44 [==============================] - 3s 65ms/step - loss: 4.6532e-04 - val_loss: 7.1319e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.5052e-04 - val_loss: 0.0027
# Epoch 19/25
# 44/44 [==============================] - 3s 69ms/step - loss: 4.2408e-04 - val_loss: 6.1526e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.2762e-04 - val_loss: 6.4338e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 62ms/step - loss: 3.7346e-04 - val_loss: 8.0042e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.8569e-04 - val_loss: 5.8073e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 53ms/step - loss: 3.7691e-04 - val_loss: 5.8559e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 50ms/step - loss: 3.8154e-04 - val_loss: 6.4909e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 51ms/step - loss: 4.6326e-04 - val_loss: 7.0173e-04
# 4/4 [==============================] - 1s 18ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  8
# Step 1. Number_of_prediction:  9  Average_MSE:  2.852227656440469  Execution_time (s):  353.448268  Learning_rate: 0.0009000000000000001
# 0:05:53.450788
# Epoch 1/25
# 44/44 [==============================] - 9s 88ms/step - loss: 0.0196 - val_loss: 0.0040
# Epoch 2/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0012 - val_loss: 0.0114
# Epoch 3/25
# 44/44 [==============================] - 3s 61ms/step - loss: 7.9841e-04 - val_loss: 0.0040
# Epoch 4/25
# 44/44 [==============================] - 3s 62ms/step - loss: 6.7521e-04 - val_loss: 0.0019
# Epoch 5/25
# 44/44 [==============================] - 3s 61ms/step - loss: 6.6366e-04 - val_loss: 8.5036e-04
# Epoch 6/25
# 44/44 [==============================] - 3s 61ms/step - loss: 6.4145e-04 - val_loss: 0.0015
# Epoch 7/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.7432e-04 - val_loss: 0.0045
# Epoch 8/25
# 44/44 [==============================] - 3s 64ms/step - loss: 6.3485e-04 - val_loss: 9.2946e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.2218e-04 - val_loss: 0.0016
# Epoch 10/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.8766e-04 - val_loss: 6.2739e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 65ms/step - loss: 4.3536e-04 - val_loss: 6.7130e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.5465e-04 - val_loss: 0.0012
# Epoch 13/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.8251e-04 - val_loss: 6.1443e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 65ms/step - loss: 5.0023e-04 - val_loss: 6.6968e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 66ms/step - loss: 3.8867e-04 - val_loss: 8.1800e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.1895e-04 - val_loss: 0.0018
# Epoch 17/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.1233e-04 - val_loss: 6.0845e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.8216e-04 - val_loss: 0.0030
# Epoch 19/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.2666e-04 - val_loss: 6.4024e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.1419e-04 - val_loss: 6.2890e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.5739e-04 - val_loss: 6.0537e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 57ms/step - loss: 3.7517e-04 - val_loss: 6.7734e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 53ms/step - loss: 3.9499e-04 - val_loss: 7.9424e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 53ms/step - loss: 3.8878e-04 - val_loss: 6.1123e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 52ms/step - loss: 4.3723e-04 - val_loss: 6.0573e-04
# 4/4 [==============================] - 1s 21ms/step
# 53/53 [==============================] - 1s 23ms/step
# Prediction:  10
# Step 1. Number_of_prediction:  11  Average_MSE:  2.542085345688564  Execution_time (s):  429.996054  Learning_rate: 0.0011
# 0:07:09.999055
# Epoch 1/25
# 44/44 [==============================] - 9s 92ms/step - loss: 0.1532 - val_loss: 0.3134
# Epoch 2/25
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0080 - val_loss: 0.0211
# Epoch 3/25
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0020 - val_loss: 0.0149
# Epoch 4/25
# 44/44 [==============================] - 3s 60ms/step - loss: 0.0017 - val_loss: 0.0107
# Epoch 5/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0013 - val_loss: 0.0056
# Epoch 6/25
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 7/25
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0010 - val_loss: 0.0038
# Epoch 8/25
# 44/44 [==============================] - 3s 57ms/step - loss: 9.7516e-04 - val_loss: 0.0033
# Epoch 9/25
# 44/44 [==============================] - 3s 57ms/step - loss: 8.5303e-04 - val_loss: 0.0055
# Epoch 10/25
# 44/44 [==============================] - 2s 56ms/step - loss: 7.9415e-04 - val_loss: 0.0025
# Epoch 11/25
# 44/44 [==============================] - 2s 57ms/step - loss: 6.9448e-04 - val_loss: 0.0017
# Epoch 12/25
# 44/44 [==============================] - 2s 56ms/step - loss: 7.3541e-04 - val_loss: 0.0035
# Epoch 13/25
# 44/44 [==============================] - 3s 57ms/step - loss: 6.5938e-04 - val_loss: 0.0024
# Epoch 14/25
# 44/44 [==============================] - 2s 56ms/step - loss: 7.0773e-04 - val_loss: 0.0012
# Epoch 15/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.8606e-04 - val_loss: 0.0023
# Epoch 16/25
# 44/44 [==============================] - 3s 57ms/step - loss: 6.0995e-04 - val_loss: 0.0058
# Epoch 17/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.7425e-04 - val_loss: 0.0015
# Epoch 18/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.8170e-04 - val_loss: 0.0015
# Epoch 19/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.2107e-04 - val_loss: 0.0010
# Epoch 20/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.8202e-04 - val_loss: 0.0016
# Epoch 21/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.5038e-04 - val_loss: 0.0018
# Epoch 22/25
# 44/44 [==============================] - 2s 51ms/step - loss: 5.2329e-04 - val_loss: 9.3077e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 50ms/step - loss: 5.5253e-04 - val_loss: 0.0027
# Epoch 24/25
# 44/44 [==============================] - 2s 47ms/step - loss: 5.1877e-04 - val_loss: 9.5721e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.2862e-04 - val_loss: 0.0017
# 4/4 [==============================] - 1s 20ms/step
# 53/53 [==============================] - 1s 22ms/step
# Prediction:  12
# Step 1. Number_of_prediction:  13  Average_MSE:  2.527714524400406  Execution_time (s):  501.915266  Learning_rate: 0.0013000000000000002
# 0:08:21.917268
# Epoch 1/25
# 44/44 [==============================] - 9s 94ms/step - loss: 0.4230 - val_loss: 0.0638
# Epoch 2/25
# 44/44 [==============================] - 3s 59ms/step - loss: 0.0113 - val_loss: 0.0361
# Epoch 3/25
# 44/44 [==============================] - 3s 64ms/step - loss: 0.0063 - val_loss: 0.0191
# Epoch 4/25
# 44/44 [==============================] - 3s 68ms/step - loss: 0.0059 - val_loss: 0.0186
# Epoch 5/25
# 44/44 [==============================] - 3s 66ms/step - loss: 0.0050 - val_loss: 0.0152
# Epoch 6/25
# 44/44 [==============================] - 3s 72ms/step - loss: 0.0043 - val_loss: 0.0154
# Epoch 7/25
# 44/44 [==============================] - 3s 63ms/step - loss: 0.0033 - val_loss: 0.0111
# Epoch 8/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0032 - val_loss: 0.0083
# Epoch 9/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0026 - val_loss: 0.0088
# Epoch 10/25
# 44/44 [==============================] - 3s 62ms/step - loss: 0.0025 - val_loss: 0.0063
# Epoch 11/25
# 44/44 [==============================] - 3s 64ms/step - loss: 0.0021 - val_loss: 0.0082
# Epoch 12/25
# 44/44 [==============================] - 3s 64ms/step - loss: 0.0020 - val_loss: 0.0088
# Epoch 13/25
# 44/44 [==============================] - 3s 63ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 14/25
# 44/44 [==============================] - 3s 63ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 15/25
# 44/44 [==============================] - 3s 64ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 16/25
# 44/44 [==============================] - 3s 63ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 17/25
# 44/44 [==============================] - 3s 62ms/step - loss: 0.0012 - val_loss: 0.0037
# Epoch 18/25
# 44/44 [==============================] - 3s 62ms/step - loss: 0.0011 - val_loss: 0.0028
# Epoch 19/25
# 44/44 [==============================] - 3s 63ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 20/25
# 44/44 [==============================] - 3s 65ms/step - loss: 9.7309e-04 - val_loss: 0.0015
# Epoch 21/25
# 44/44 [==============================] - 3s 63ms/step - loss: 8.7167e-04 - val_loss: 0.0016
# Epoch 22/25
# 44/44 [==============================] - 3s 61ms/step - loss: 8.5255e-04 - val_loss: 0.0016
# Epoch 23/25
# 44/44 [==============================] - 3s 62ms/step - loss: 8.8572e-04 - val_loss: 0.0022
# Epoch 24/25
# 44/44 [==============================] - 2s 55ms/step - loss: 7.7653e-04 - val_loss: 0.0019
# Epoch 25/25
# 44/44 [==============================] - 3s 62ms/step - loss: 7.6285e-04 - val_loss: 0.0023
# 4/4 [==============================] - 1s 16ms/step
# 53/53 [==============================] - 1s 19ms/step
# Prediction:  14
# Step 1. Number_of_prediction:  15  Average_MSE:  2.5897495130442967  Execution_time (s):  580.730218  Learning_rate: 0.0015
# 0:09:40.732260
# Epoch 1/25
# 44/44 [==============================] - 9s 89ms/step - loss: 0.0180 - val_loss: 0.0029
# Epoch 2/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 3/25
# 44/44 [==============================] - 3s 70ms/step - loss: 8.2735e-04 - val_loss: 0.0041
# Epoch 4/25
# 44/44 [==============================] - 3s 63ms/step - loss: 6.5625e-04 - val_loss: 0.0010
# Epoch 5/25
# 44/44 [==============================] - 3s 61ms/step - loss: 5.9740e-04 - val_loss: 5.9922e-04
# Epoch 6/25
# 44/44 [==============================] - 3s 61ms/step - loss: 6.2816e-04 - val_loss: 6.0190e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 67ms/step - loss: 5.1673e-04 - val_loss: 0.0030
# Epoch 8/25
# 44/44 [==============================] - 3s 67ms/step - loss: 5.3932e-04 - val_loss: 6.5754e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.8587e-04 - val_loss: 0.0010
# Epoch 10/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.6533e-04 - val_loss: 5.6360e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 67ms/step - loss: 4.0889e-04 - val_loss: 5.9865e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.4693e-04 - val_loss: 0.0025
# Epoch 13/25
# 44/44 [==============================] - 3s 67ms/step - loss: 5.1684e-04 - val_loss: 6.0310e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.6025e-04 - val_loss: 0.0013
# Epoch 15/25
# 44/44 [==============================] - 3s 64ms/step - loss: 3.8632e-04 - val_loss: 5.8603e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 74ms/step - loss: 3.8818e-04 - val_loss: 0.0016
# Epoch 17/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.4841e-04 - val_loss: 6.5153e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.3493e-04 - val_loss: 0.0031
# Epoch 19/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.7832e-04 - val_loss: 6.8517e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.1338e-04 - val_loss: 5.4731e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.4889e-04 - val_loss: 6.6620e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.7334e-04 - val_loss: 8.3598e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.1750e-04 - val_loss: 0.0012
# Epoch 24/25
# 44/44 [==============================] - 2s 53ms/step - loss: 3.7790e-04 - val_loss: 5.9781e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 51ms/step - loss: 4.4841e-04 - val_loss: 6.0287e-04
# 4/4 [==============================] - 1s 22ms/step
# 53/53 [==============================] - 1s 23ms/step
# Prediction:  16
# Step 1. Number_of_prediction:  17  Average_MSE:  2.4654784994045915  Execution_time (s):  659.086132  Learning_rate: 0.0017000000000000001
# 0:10:59.086132
# Epoch 1/25
# 44/44 [==============================] - 10s 108ms/step - loss: 0.0040 - val_loss: 0.0060
# Epoch 2/25
# 44/44 [==============================] - 3s 68ms/step - loss: 8.2491e-04 - val_loss: 6.4722e-04
# Epoch 3/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.9791e-04 - val_loss: 6.0283e-04
# Epoch 4/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.9886e-04 - val_loss: 5.5615e-04
# Epoch 5/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.0431e-04 - val_loss: 0.0011
# Epoch 6/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.4543e-04 - val_loss: 0.0011
# Epoch 7/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.1523e-04 - val_loss: 0.0017
# Epoch 8/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.4480e-04 - val_loss: 6.1875e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 71ms/step - loss: 4.3197e-04 - val_loss: 8.6351e-04
# Epoch 10/25
# 44/44 [==============================] - 3s 69ms/step - loss: 5.0036e-04 - val_loss: 0.0018
# Epoch 11/25
# 44/44 [==============================] - 3s 65ms/step - loss: 3.9925e-04 - val_loss: 5.3930e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 67ms/step - loss: 3.8492e-04 - val_loss: 0.0023
# Epoch 13/25
# 44/44 [==============================] - 3s 67ms/step - loss: 3.6425e-04 - val_loss: 5.4452e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 66ms/step - loss: 5.0863e-04 - val_loss: 0.0010
# Epoch 15/25
# 44/44 [==============================] - 3s 62ms/step - loss: 3.6090e-04 - val_loss: 5.3983e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.1329e-04 - val_loss: 0.0018
# Epoch 17/25
# 44/44 [==============================] - 3s 63ms/step - loss: 3.3022e-04 - val_loss: 5.4067e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.2449e-04 - val_loss: 0.0020
# Epoch 19/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.4052e-04 - val_loss: 5.9602e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 69ms/step - loss: 5.1066e-04 - val_loss: 0.0011
# Epoch 21/25
# 44/44 [==============================] - 3s 59ms/step - loss: 3.5569e-04 - val_loss: 0.0010
# Epoch 22/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.7438e-04 - val_loss: 4.8938e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 54ms/step - loss: 3.9489e-04 - val_loss: 7.5365e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.3265e-04 - val_loss: 4.8113e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 59ms/step - loss: 3.4773e-04 - val_loss: 7.3682e-04
# 4/4 [==============================] - 1s 23ms/step
# 53/53 [==============================] - 1s 24ms/step
# Prediction:  18
# Step 1. Number_of_prediction:  19  Average_MSE:  2.322901934798816  Execution_time (s):  740.092678  Learning_rate: 0.0019000000000000002
# 0:12:20.092678
# Epoch 1/25
# 44/44 [==============================] - 10s 98ms/step - loss: 0.0046 - val_loss: 0.0029
# Epoch 2/25
# 44/44 [==============================] - 3s 64ms/step - loss: 8.2548e-04 - val_loss: 0.0026
# Epoch 3/25
# 44/44 [==============================] - 3s 65ms/step - loss: 7.0169e-04 - val_loss: 8.0263e-04
# Epoch 4/25
# 44/44 [==============================] - 3s 66ms/step - loss: 6.4656e-04 - val_loss: 0.0011
# Epoch 5/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.4762e-04 - val_loss: 0.0015
# Epoch 6/25
# 44/44 [==============================] - 3s 68ms/step - loss: 5.9666e-04 - val_loss: 5.9629e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.6486e-04 - val_loss: 0.0019
# Epoch 8/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.6025e-04 - val_loss: 0.0017
# Epoch 9/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.4763e-04 - val_loss: 8.2437e-04
# Epoch 10/25
# 44/44 [==============================] - 3s 66ms/step - loss: 5.0690e-04 - val_loss: 6.1006e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 74ms/step - loss: 4.5030e-04 - val_loss: 5.8855e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 67ms/step - loss: 3.7355e-04 - val_loss: 0.0022
# Epoch 13/25
# 44/44 [==============================] - 3s 67ms/step - loss: 4.0069e-04 - val_loss: 6.7131e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 65ms/step - loss: 4.5671e-04 - val_loss: 8.3613e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 67ms/step - loss: 3.2868e-04 - val_loss: 5.4906e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 74ms/step - loss: 3.9906e-04 - val_loss: 0.0016
# Epoch 17/25
# 44/44 [==============================] - 3s 68ms/step - loss: 3.4590e-04 - val_loss: 5.4461e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 72ms/step - loss: 4.5487e-04 - val_loss: 0.0018
# Epoch 19/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.4153e-04 - val_loss: 5.2523e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 61ms/step - loss: 5.5441e-04 - val_loss: 0.0012
# Epoch 21/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.7136e-04 - val_loss: 6.9973e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.8740e-04 - val_loss: 5.2346e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.1637e-04 - val_loss: 5.0255e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 67ms/step - loss: 4.3118e-04 - val_loss: 5.3009e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 63ms/step - loss: 3.4428e-04 - val_loss: 8.7077e-04
# 4/4 [==============================] - 1s 19ms/step
# 53/53 [==============================] - 1s 22ms/step
# Prediction:  20
# Step 1. Number_of_prediction:  21  Average_MSE:  2.218960724605084  Execution_time (s):  823.511363  Learning_rate: 0.0021
# 0:13:43.512619
# Epoch 1/25
# 44/44 [==============================] - 9s 86ms/step - loss: 0.0972 - val_loss: 0.0576
# Epoch 2/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0019 - val_loss: 0.0100
# Epoch 3/25
# 44/44 [==============================] - 3s 59ms/step - loss: 8.7395e-04 - val_loss: 0.0025
# Epoch 4/25
# 44/44 [==============================] - 3s 60ms/step - loss: 7.7411e-04 - val_loss: 0.0018
# Epoch 5/25
# 44/44 [==============================] - 3s 62ms/step - loss: 7.2838e-04 - val_loss: 0.0013
# Epoch 6/25
# 44/44 [==============================] - 3s 63ms/step - loss: 7.2518e-04 - val_loss: 9.9537e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 62ms/step - loss: 6.5046e-04 - val_loss: 8.5920e-04
# Epoch 8/25
# 44/44 [==============================] - 3s 62ms/step - loss: 7.0002e-04 - val_loss: 9.7527e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 62ms/step - loss: 5.9135e-04 - val_loss: 0.0012
# Epoch 10/25
# 44/44 [==============================] - 3s 61ms/step - loss: 5.5332e-04 - val_loss: 6.7378e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 66ms/step - loss: 5.5112e-04 - val_loss: 0.0013
# Epoch 12/25
# 44/44 [==============================] - 3s 68ms/step - loss: 5.3947e-04 - val_loss: 0.0012
# Epoch 13/25
# 44/44 [==============================] - 3s 65ms/step - loss: 5.2838e-04 - val_loss: 9.8971e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.2312e-04 - val_loss: 7.7020e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.6490e-04 - val_loss: 7.5612e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.8711e-04 - val_loss: 9.6148e-04
# Epoch 17/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.7700e-04 - val_loss: 7.7860e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.3207e-04 - val_loss: 0.0013
# Epoch 19/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.9052e-04 - val_loss: 6.6121e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.7089e-04 - val_loss: 5.9985e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.0818e-04 - val_loss: 7.7183e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.8706e-04 - val_loss: 5.9065e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.3367e-04 - val_loss: 6.0487e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.6907e-04 - val_loss: 8.0096e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 52ms/step - loss: 4.7006e-04 - val_loss: 6.0466e-04
# 4/4 [==============================] - 1s 25ms/step
# 53/53 [==============================] - 1s 24ms/step
# Prediction:  22
# Step 1. Number_of_prediction:  23  Average_MSE:  2.12607606071968  Execution_time (s):  899.516431  Learning_rate: 0.0023
# 0:14:59.522783
# Epoch 1/25
# 44/44 [==============================] - 10s 94ms/step - loss: 0.0061 - val_loss: 0.0025
# Epoch 2/25
# 44/44 [==============================] - 3s 59ms/step - loss: 8.2941e-04 - val_loss: 0.0023
# Epoch 3/25
# 44/44 [==============================] - 3s 60ms/step - loss: 6.2697e-04 - val_loss: 7.3912e-04
# Epoch 4/25
# 44/44 [==============================] - 3s 59ms/step - loss: 6.2611e-04 - val_loss: 9.8084e-04
# Epoch 5/25
# 44/44 [==============================] - 3s 61ms/step - loss: 6.5771e-04 - val_loss: 6.0986e-04
# Epoch 6/25
# 44/44 [==============================] - 3s 62ms/step - loss: 5.2715e-04 - val_loss: 7.7422e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.4289e-04 - val_loss: 0.0021
# Epoch 8/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.5589e-04 - val_loss: 0.0015
# Epoch 9/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.0286e-04 - val_loss: 0.0019
# Epoch 10/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.1113e-04 - val_loss: 5.6914e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.4324e-04 - val_loss: 7.6661e-04
# Epoch 12/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.7181e-04 - val_loss: 0.0022
# Epoch 13/25
# 44/44 [==============================] - 2s 57ms/step - loss: 3.8419e-04 - val_loss: 5.1309e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.7259e-04 - val_loss: 0.0013
# Epoch 15/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.3419e-04 - val_loss: 5.1396e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.0808e-04 - val_loss: 0.0015
# Epoch 17/25
# 44/44 [==============================] - 2s 55ms/step - loss: 3.4472e-04 - val_loss: 4.9712e-04
# Epoch 18/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.4117e-04 - val_loss: 0.0024
# Epoch 19/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.4621e-04 - val_loss: 0.0011
# Epoch 20/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.9270e-04 - val_loss: 0.0012
# Epoch 21/25
# 44/44 [==============================] - 3s 57ms/step - loss: 3.6437e-04 - val_loss: 8.5540e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 50ms/step - loss: 4.0437e-04 - val_loss: 4.8198e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 51ms/step - loss: 4.1447e-04 - val_loss: 4.7882e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 47ms/step - loss: 4.1170e-04 - val_loss: 5.0920e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 48ms/step - loss: 3.5154e-04 - val_loss: 0.0011
# 4/4 [==============================] - 1s 18ms/step
# 53/53 [==============================] - 1s 23ms/step
# Prediction:  24
# Step 1. Number_of_prediction:  25  Average_MSE:  2.0662592381005003  Execution_time (s):  971.959935  Learning_rate: 0.0025
# 0:16:11.963449
# Epoch 1/25
# 44/44 [==============================] - 9s 92ms/step - loss: 0.0316 - val_loss: 0.0343
# Epoch 2/25
# 44/44 [==============================] - 3s 63ms/step - loss: 0.0015 - val_loss: 0.0093
# Epoch 3/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0012 - val_loss: 0.0056
# Epoch 4/25
# 44/44 [==============================] - 3s 63ms/step - loss: 8.1179e-04 - val_loss: 0.0029
# Epoch 5/25
# 44/44 [==============================] - 3s 62ms/step - loss: 6.6782e-04 - val_loss: 0.0019
# Epoch 6/25
# 44/44 [==============================] - 3s 61ms/step - loss: 6.1964e-04 - val_loss: 0.0018
# Epoch 7/25
# 44/44 [==============================] - 3s 62ms/step - loss: 5.1291e-04 - val_loss: 0.0037
# Epoch 8/25
# 44/44 [==============================] - 3s 61ms/step - loss: 5.3324e-04 - val_loss: 0.0016
# Epoch 9/25
# 44/44 [==============================] - 3s 62ms/step - loss: 5.1075e-04 - val_loss: 0.0017
# Epoch 10/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.8906e-04 - val_loss: 0.0014
# Epoch 11/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.6738e-04 - val_loss: 6.1707e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.2487e-04 - val_loss: 0.0045
# Epoch 13/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.5996e-04 - val_loss: 7.8576e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.0097e-04 - val_loss: 7.0233e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 65ms/step - loss: 3.5873e-04 - val_loss: 6.4016e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.0602e-04 - val_loss: 0.0017
# Epoch 17/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.0742e-04 - val_loss: 6.7651e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.4507e-04 - val_loss: 0.0022
# Epoch 19/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.8560e-04 - val_loss: 6.4909e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.1226e-04 - val_loss: 0.0011
# Epoch 21/25
# 44/44 [==============================] - 3s 57ms/step - loss: 3.4709e-04 - val_loss: 9.4666e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.7144e-04 - val_loss: 5.6808e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.3276e-04 - val_loss: 0.0025
# Epoch 24/25
# 44/44 [==============================] - 2s 54ms/step - loss: 3.9614e-04 - val_loss: 5.8193e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.0802e-04 - val_loss: 7.8247e-04
# 4/4 [==============================] - 1s 23ms/step
# 53/53 [==============================] - 1s 22ms/step
# Prediction:  26
# Step 1. Number_of_prediction:  27  Average_MSE:  2.0043123170458763  Execution_time (s):  1048.72757  Learning_rate: 0.0027
# 0:17:28.729731
# Epoch 1/25
# 44/44 [==============================] - 10s 84ms/step - loss: 0.0146 - val_loss: 0.0064
# Epoch 2/25
# 44/44 [==============================] - 3s 59ms/step - loss: 9.5289e-04 - val_loss: 0.0020
# Epoch 3/25
# 44/44 [==============================] - 3s 58ms/step - loss: 7.6587e-04 - val_loss: 0.0021
# Epoch 4/25
# 44/44 [==============================] - 3s 57ms/step - loss: 6.6079e-04 - val_loss: 7.0818e-04
# Epoch 5/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.7268e-04 - val_loss: 7.9799e-04
# Epoch 6/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.5318e-04 - val_loss: 7.0217e-04
# Epoch 7/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.0207e-04 - val_loss: 9.8442e-04
# Epoch 8/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.2122e-04 - val_loss: 5.5738e-04
# Epoch 9/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.5482e-04 - val_loss: 0.0029
# Epoch 10/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.6600e-04 - val_loss: 5.3849e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.2780e-04 - val_loss: 7.1814e-04
# Epoch 12/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.1070e-04 - val_loss: 0.0024
# Epoch 13/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.0189e-04 - val_loss: 7.8845e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.3215e-04 - val_loss: 5.4318e-04
# Epoch 15/25
# 44/44 [==============================] - 2s 55ms/step - loss: 3.4483e-04 - val_loss: 5.4148e-04
# Epoch 16/25
# 44/44 [==============================] - 2s 55ms/step - loss: 3.9971e-04 - val_loss: 0.0012
# Epoch 17/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.8735e-04 - val_loss: 6.6080e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.5592e-04 - val_loss: 0.0025
# Epoch 19/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.2790e-04 - val_loss: 5.3026e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.9145e-04 - val_loss: 0.0015
# Epoch 21/25
# 44/44 [==============================] - 3s 57ms/step - loss: 3.5732e-04 - val_loss: 0.0010
# Epoch 22/25
# 44/44 [==============================] - 2s 53ms/step - loss: 3.8404e-04 - val_loss: 6.0506e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 52ms/step - loss: 3.9640e-04 - val_loss: 0.0011
# Epoch 24/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.5755e-04 - val_loss: 5.0056e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.7512e-04 - val_loss: 6.5275e-04
# 4/4 [==============================] - 1s 20ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  28
# Step 1. Number_of_prediction:  29  Average_MSE:  1.938453016653041  Execution_time (s):  1121.819162  Learning_rate: 0.0029
# 0:18:41.821238
# Epoch 1/25
# 44/44 [==============================] - 10s 93ms/step - loss: 0.0824 - val_loss: 0.0443
# Epoch 2/25
# 44/44 [==============================] - 3s 62ms/step - loss: 0.0014 - val_loss: 0.0103
# Epoch 3/25
# 44/44 [==============================] - 3s 60ms/step - loss: 9.0099e-04 - val_loss: 0.0024
# Epoch 4/25
# 44/44 [==============================] - 3s 61ms/step - loss: 7.7078e-04 - val_loss: 0.0012
# Epoch 5/25
# 44/44 [==============================] - 3s 60ms/step - loss: 7.7437e-04 - val_loss: 0.0028
# Epoch 6/25
# 44/44 [==============================] - 3s 60ms/step - loss: 6.5264e-04 - val_loss: 8.8239e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 60ms/step - loss: 6.2830e-04 - val_loss: 0.0010
# Epoch 8/25
# 44/44 [==============================] - 3s 60ms/step - loss: 6.7712e-04 - val_loss: 7.5597e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 58ms/step - loss: 6.2812e-04 - val_loss: 0.0019
# Epoch 10/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.2515e-04 - val_loss: 6.2740e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.5944e-04 - val_loss: 5.7064e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.3777e-04 - val_loss: 7.3503e-04
# Epoch 13/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.6951e-04 - val_loss: 8.8404e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.8450e-04 - val_loss: 5.6868e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.1791e-04 - val_loss: 0.0011
# Epoch 16/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.3538e-04 - val_loss: 0.0015
# Epoch 17/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.2850e-04 - val_loss: 6.2375e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.7298e-04 - val_loss: 0.0046
# Epoch 19/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.7179e-04 - val_loss: 7.3009e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.3629e-04 - val_loss: 5.5602e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 49ms/step - loss: 3.6239e-04 - val_loss: 5.6071e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 52ms/step - loss: 3.7930e-04 - val_loss: 5.5976e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 48ms/step - loss: 4.1000e-04 - val_loss: 7.9878e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 48ms/step - loss: 4.5336e-04 - val_loss: 5.7930e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 51ms/step - loss: 4.8278e-04 - val_loss: 6.3649e-04
# 4/4 [==============================] - 1s 17ms/step
# 53/53 [==============================] - 1s 18ms/step
# Prediction:  30
# Step 1. Number_of_prediction:  31  Average_MSE:  1.8987429685533097  Execution_time (s):  1196.30202  Learning_rate: 0.0031
# 0:19:56.303212
# Epoch 1/25
# 44/44 [==============================] - 9s 91ms/step - loss: 0.0086 - val_loss: 0.0073
# Epoch 2/25
# 44/44 [==============================] - 3s 60ms/step - loss: 8.4935e-04 - val_loss: 8.1166e-04
# Epoch 3/25
# 44/44 [==============================] - 3s 59ms/step - loss: 6.1836e-04 - val_loss: 8.9643e-04
# Epoch 4/25
# 44/44 [==============================] - 2s 57ms/step - loss: 6.0681e-04 - val_loss: 6.0672e-04
# Epoch 5/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.5697e-04 - val_loss: 7.6514e-04
# Epoch 6/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.4474e-04 - val_loss: 6.3266e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 70ms/step - loss: 4.2591e-04 - val_loss: 0.0021
# Epoch 8/25
# 44/44 [==============================] - 3s 68ms/step - loss: 4.9008e-04 - val_loss: 5.5682e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.8624e-04 - val_loss: 7.2389e-04
# Epoch 10/25
# 44/44 [==============================] - 3s 67ms/step - loss: 4.8474e-04 - val_loss: 0.0019
# Epoch 11/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.3124e-04 - val_loss: 6.3071e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.0543e-04 - val_loss: 0.0013
# Epoch 13/25
# 44/44 [==============================] - 3s 64ms/step - loss: 3.5831e-04 - val_loss: 6.0539e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 65ms/step - loss: 4.9710e-04 - val_loss: 5.1068e-04
# Epoch 15/25
# ...
# 44/44 [==============================] - 3s 66ms/step - loss: 3.6170e-04 - val_loss: 5.8086e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.1224e-04 - val_loss: 9.5304e-04
# Epoch 17/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.9759e-04 - val_loss: 5.1715e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.3464e-04 - val_loss: 0.0023
# Epoch 19/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.1199e-04 - val_loss: 5.0313e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 51ms/step - loss: 4.3326e-04 - val_loss: 6.3665e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 50ms/step - loss: 3.5717e-04 - val_loss: 7.0519e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 50ms/step - loss: 3.8147e-04 - val_loss: 5.3201e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.2180e-04 - val_loss: 0.0014
# Epoch 24/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.0378e-04 - val_loss: 7.2541e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 76ms/step - loss: 4.3528e-04 - val_loss: 6.5862e-04
# 4/4 [==============================] - 2s 26ms/step
# 53/53 [==============================] - 1s 23ms/step
# Prediction:  38
# Step 1. Number_of_prediction:  39  Average_MSE:  1.8845822457654027  Execution_time (s):  1506.341224  Learning_rate: 0.0039
# 0:25:06.343410
# Epoch 1/25
# 44/44 [==============================] - 11s 94ms/step - loss: 0.0284 - val_loss: 0.0107
# Epoch 2/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 3/25
# 44/44 [==============================] - 3s 61ms/step - loss: 8.4034e-04 - val_loss: 0.0015
# Epoch 4/25
# 44/44 [==============================] - 3s 61ms/step - loss: 7.2934e-04 - val_loss: 5.9796e-04
# Epoch 5/25
# 44/44 [==============================] - 3s 61ms/step - loss: 6.9727e-04 - val_loss: 0.0016
# Epoch 6/25
# 44/44 [==============================] - 3s 60ms/step - loss: 6.0724e-04 - val_loss: 7.0363e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.2063e-04 - val_loss: 0.0021
# Epoch 8/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.5216e-04 - val_loss: 0.0016
# Epoch 9/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.8616e-04 - val_loss: 0.0020
# Epoch 10/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.5910e-04 - val_loss: 5.8869e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.7514e-04 - val_loss: 5.9313e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.2933e-04 - val_loss: 0.0025
# Epoch 13/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.0131e-04 - val_loss: 5.7329e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.7873e-04 - val_loss: 0.0013
# Epoch 15/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.8064e-04 - val_loss: 5.9517e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.1927e-04 - val_loss: 0.0029
# Epoch 17/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.8834e-04 - val_loss: 5.4868e-04
# Epoch 18/25
# 44/44 [==============================] - 2s 50ms/step - loss: 4.7886e-04 - val_loss: 0.0019
# Epoch 19/25
# 44/44 [==============================] - 2s 51ms/step - loss: 5.3823e-04 - val_loss: 9.0995e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 47ms/step - loss: 5.0934e-04 - val_loss: 0.0011
# Epoch 21/25
# 44/44 [==============================] - 2s 46ms/step - loss: 4.1192e-04 - val_loss: 0.0012
# Epoch 22/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.3216e-04 - val_loss: 5.2333e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 78ms/step - loss: 4.4748e-04 - val_loss: 0.0011
# Epoch 24/25
# 44/44 [==============================] - 3s 73ms/step - loss: 4.7163e-04 - val_loss: 7.9500e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 77ms/step - loss: 4.1488e-04 - val_loss: 0.0023
# 4/4 [==============================] - 2s 28ms/step
# 53/53 [==============================] - 1s 25ms/step
# Prediction:  40
# Step 1. Number_of_prediction:  41  Average_MSE:  1.9198172632063824  Execution_time (s):  1584.133729  Learning_rate: 0.0041
# 0:26:24.133729
# Epoch 1/25
# 44/44 [==============================] - 13s 103ms/step - loss: 0.0065 - val_loss: 6.1657e-04
# Epoch 2/25
# 44/44 [==============================] - 3s 64ms/step - loss: 8.2216e-04 - val_loss: 5.3462e-04
# Epoch 3/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.9798e-04 - val_loss: 9.4936e-04
# Epoch 4/25
# 44/44 [==============================] - 3s 63ms/step - loss: 7.3246e-04 - val_loss: 0.0015
# Epoch 5/25
# 44/44 [==============================] - 3s 63ms/step - loss: 6.1664e-04 - val_loss: 0.0013
# Epoch 6/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.6787e-04 - val_loss: 0.0019
# Epoch 7/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.8553e-04 - val_loss: 0.0017
# Epoch 8/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.8302e-04 - val_loss: 9.7844e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 65ms/step - loss: 4.3851e-04 - val_loss: 5.2709e-04
# Epoch 10/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.4447e-04 - val_loss: 0.0034
# Epoch 11/25
# 44/44 [==============================] - 3s 68ms/step - loss: 4.6476e-04 - val_loss: 0.0011
# Epoch 12/25
# 44/44 [==============================] - 3s 66ms/step - loss: 5.9670e-04 - val_loss: 0.0026
# Epoch 13/25
# 44/44 [==============================] - 3s 62ms/step - loss: 6.5442e-04 - val_loss: 5.0351e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.7159e-04 - val_loss: 0.0011
# Epoch 15/25
# 44/44 [==============================] - 3s 64ms/step - loss: 3.4237e-04 - val_loss: 7.2879e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.1204e-04 - val_loss: 6.2446e-04
# Epoch 17/25
# 44/44 [==============================] - 3s 64ms/step - loss: 3.7097e-04 - val_loss: 5.0588e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 59ms/step - loss: 6.8630e-04 - val_loss: 0.0020
# Epoch 19/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.7813e-04 - val_loss: 4.9667e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 61ms/step - loss: 6.3333e-04 - val_loss: 6.1641e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.8134e-04 - val_loss: 8.5170e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.5933e-04 - val_loss: 0.0011
# Epoch 23/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.9492e-04 - val_loss: 7.8059e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.2418e-04 - val_loss: 8.0191e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.2274e-04 - val_loss: 0.0040
# 4/4 [==============================] - 1s 20ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  42
# Step 1. Number_of_prediction:  43  Average_MSE:  2.0440835808776483  Execution_time (s):  1666.954832  Learning_rate: 0.004300000000000001
# 0:27:46.956987
# Epoch 1/25
# 44/44 [==============================] - 12s 88ms/step - loss: 0.0121 - val_loss: 0.0043
# Epoch 2/25
# 44/44 [==============================] - 3s 64ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 3/25
# 44/44 [==============================] - 3s 64ms/step - loss: 9.0232e-04 - val_loss: 0.0024
# Epoch 4/25
# 44/44 [==============================] - 3s 62ms/step - loss: 7.4022e-04 - val_loss: 8.2454e-04
# Epoch 5/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.8636e-04 - val_loss: 0.0024
# Epoch 6/25
# 44/44 [==============================] - 3s 61ms/step - loss: 5.8575e-04 - val_loss: 5.3524e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.4305e-04 - val_loss: 0.0026
# Epoch 8/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.2642e-04 - val_loss: 6.8318e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.7401e-04 - val_loss: 5.1406e-04
# Epoch 10/25
# 44/44 [==============================] - 3s 59ms/step - loss: 6.6023e-04 - val_loss: 9.9062e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.4589e-04 - val_loss: 0.0014
# Epoch 12/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.1206e-04 - val_loss: 0.0030
# Epoch 13/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.6134e-04 - val_loss: 4.8228e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.7736e-04 - val_loss: 6.2043e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 63ms/step - loss: 3.3556e-04 - val_loss: 4.8332e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 68ms/step - loss: 4.0367e-04 - val_loss: 0.0013
# Epoch 17/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.0688e-04 - val_loss: 7.0764e-04
# Epoch 18/25
# 44/44 [==============================] - 2s 56ms/step - loss: 7.3811e-04 - val_loss: 0.0016
# Epoch 19/25
# 44/44 [==============================] - 2s 50ms/step - loss: 4.1231e-04 - val_loss: 6.1950e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.9622e-04 - val_loss: 4.6747e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 48ms/step - loss: 4.2255e-04 - val_loss: 7.5542e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 48ms/step - loss: 5.0774e-04 - val_loss: 0.0011
# Epoch 23/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.6517e-04 - val_loss: 8.2925e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 52ms/step - loss: 3.9310e-04 - val_loss: 0.0010
# Epoch 25/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.0046e-04 - val_loss: 0.0029
# 4/4 [==============================] - 1s 21ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  44
# Step 1. Number_of_prediction:  45  Average_MSE:  2.109177961626585  Execution_time (s):  1743.338122  Learning_rate: 0.0045000000000000005
# 0:29:03.344721
# Epoch 1/25
# 44/44 [==============================] - 9s 83ms/step - loss: 0.0179 - val_loss: 0.0100
# Epoch 2/25
# 44/44 [==============================] - 2s 55ms/step - loss: 0.0010 - val_loss: 0.0079
# Epoch 3/25
# 44/44 [==============================] - 2s 55ms/step - loss: 8.5985e-04 - val_loss: 0.0020
# Epoch 4/25
# 44/44 [==============================] - 2s 54ms/step - loss: 6.4498e-04 - val_loss: 0.0011
# Epoch 5/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.5258e-04 - val_loss: 0.0013
# Epoch 6/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.5644e-04 - val_loss: 5.6499e-04
# Epoch 7/25
# 44/44 [==============================] - 2s 52ms/step - loss: 4.4529e-04 - val_loss: 0.0012
# Epoch 8/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.6874e-04 - val_loss: 9.0780e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.9357e-04 - val_loss: 0.0021
# Epoch 10/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.7663e-04 - val_loss: 0.0017
# Epoch 11/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.1900e-04 - val_loss: 9.3962e-04
# Epoch 12/25
# 44/44 [==============================] - 2s 55ms/step - loss: 3.8899e-04 - val_loss: 0.0015
# Epoch 13/25
# 44/44 [==============================] - 2s 54ms/step - loss: 3.7094e-04 - val_loss: 5.1233e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.7078e-04 - val_loss: 9.2711e-04
# Epoch 15/25
# 44/44 [==============================] - 2s 54ms/step - loss: 3.4904e-04 - val_loss: 6.4574e-04
# Epoch 16/25
# 44/44 [==============================] - 2s 54ms/step - loss: 3.9997e-04 - val_loss: 0.0031
# Epoch 17/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.7708e-04 - val_loss: 5.0084e-04
# Epoch 18/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.7205e-04 - val_loss: 0.0013
# Epoch 19/25
# 44/44 [==============================] - 2s 51ms/step - loss: 4.1756e-04 - val_loss: 4.7760e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 49ms/step - loss: 4.9166e-04 - val_loss: 6.7414e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 47ms/step - loss: 3.7515e-04 - val_loss: 0.0010
# Epoch 22/25
# 44/44 [==============================] - 2s 47ms/step - loss: 4.5636e-04 - val_loss: 6.8231e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 51ms/step - loss: 6.1339e-04 - val_loss: 5.9526e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 51ms/step - loss: 4.0612e-04 - val_loss: 6.8340e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.8543e-04 - val_loss: 0.0029
# 4/4 [==============================] - 1s 20ms/step
# 53/53 [==============================] - 1s 20ms/step
# Prediction:  46
# Step 1. Number_of_prediction:  47  Average_MSE:  2.157329358002896  Execution_time (s):  1811.956462  Learning_rate: 0.0047
# 0:30:11.958384
# Epoch 1/25
# 44/44 [==============================] - 9s 81ms/step - loss: 0.0206 - val_loss: 0.0189
# Epoch 2/25
# 44/44 [==============================] - 2s 54ms/step - loss: 9.2682e-04 - val_loss: 0.0030
# Epoch 3/25
# 44/44 [==============================] - 2s 53ms/step - loss: 7.5922e-04 - val_loss: 6.0700e-04
# Epoch 4/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.8648e-04 - val_loss: 0.0013
# Epoch 5/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.4775e-04 - val_loss: 8.3538e-04
# Epoch 6/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.9421e-04 - val_loss: 7.5951e-04
# Epoch 7/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.6451e-04 - val_loss: 0.0011
# Epoch 8/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.4040e-04 - val_loss: 0.0011
# Epoch 9/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.8913e-04 - val_loss: 0.0015
# Epoch 10/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.8424e-04 - val_loss: 5.4181e-04
# Epoch 11/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.6516e-04 - val_loss: 5.2670e-04
# Epoch 12/25
# 44/44 [==============================] - 2s 55ms/step - loss: 3.8668e-04 - val_loss: 0.0023
# Epoch 13/25
# 44/44 [==============================] - 2s 52ms/step - loss: 3.6708e-04 - val_loss: 9.1941e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.7580e-04 - val_loss: 0.0015
# Epoch 15/25
# 44/44 [==============================] - 2s 53ms/step - loss: 3.5226e-04 - val_loss: 7.8567e-04
# Epoch 16/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.1162e-04 - val_loss: 0.0026
# Epoch 17/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.4643e-04 - val_loss: 6.2257e-04
# Epoch 18/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.5011e-04 - val_loss: 0.0021
# Epoch 19/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.2029e-04 - val_loss: 4.9842e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.7766e-04 - val_loss: 6.6526e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 49ms/step - loss: 4.2436e-04 - val_loss: 7.5171e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 44ms/step - loss: 3.9723e-04 - val_loss: 5.0093e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 44ms/step - loss: 4.8481e-04 - val_loss: 5.4544e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 44ms/step - loss: 4.2096e-04 - val_loss: 5.6280e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 44ms/step - loss: 3.5751e-04 - val_loss: 0.0016
# 4/4 [==============================] - 1s 13ms/step
# 53/53 [==============================] - 1s 16ms/step
# Prediction:  48
# Step 1. Number_of_prediction:  49  Average_MSE:  2.145340753733671  Execution_time (s):  1878.967644  Learning_rate: 0.004900000000000001
# 0:31:18.970051
# Sending file...
# File sent successfully
