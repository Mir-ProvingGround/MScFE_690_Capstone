# %%
#Waiting for prediction order
import socket

# Create a socket object
server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)

# Get local machine name
host = socket.gethostname()
port = 8999
msg='none'
# Bind to the port
server_socket.bind((host, port))

server_socket.listen(5)
print("Standby for prediction order")
while True:
    # Establish a connection
    client_socket, addr = server_socket.accept()
    print("Receive prediction order")
    # Receive no more than 1024 bytes
    msg = (client_socket.recv(1024)).decode('utf-8')
    client_socket.close()
    break

if(msg=='MSFT'):
    #Time recording
    import datetime
    startCNNs_LSTMs = datetime.datetime.now()

    #Library list
    # Library imports
    import keras
    from sklearn.metrics import mean_squared_error
    from keras.models import Model, Sequential
    from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, LeakyReLU, LSTM, Input, Activation
    from keras import optimizers, regularizers
    import numpy as np
    import pandas as pd
    import tensorflow as tf
    import yfinance as yf
    from sklearn import preprocessing
    import matplotlib.pyplot as plt
    from keras.callbacks import EarlyStopping, ReduceLROnPlateau
    import ta
    #Set random parameter
    np.random.seed(4)
    tf.random.set_seed(4)

    # Get the data for the stock MSFT between '2012-02-01' to '2019-03-05'
    df = yf.download('MSFT','2012-02-01','2019-03-05')
    # Heiken Ashi calculation
    heiken_ashi_df = df.copy()
    heiken_ashi_df['HA_Close'] = (df['Open'] + df['High'] + df['Low'] + df['Close']) / 4
    heiken_ashi_df['HA_Open'] = (df['Open'] + df['Close']) / 2
    heiken_ashi_df['HA_High'] = df[['Open', 'Close', 'High']].max(axis=1)
    heiken_ashi_df['HA_Low'] = df[['Open', 'Close', 'Low']].min(axis=1)

    # Additional technical indicators
    df['RSI'] = ta.momentum.rsi(df['Close'], window=14)
    df['MACD'] = ta.trend.macd_diff(df['Close'])
    df['MA_10'] = df['Close'].rolling(window=10).mean()

    # Combine all features into one DataFrame
    df = df.join(heiken_ashi_df[['HA_Open', 'HA_High', 'HA_Low', 'HA_Close']])
    df.dropna(inplace=True)

    next_day_closed = df['Close'].shift(-1, axis=0)
    next_day_closed.drop(index=next_day_closed.index[len(next_day_closed)-1], axis=0, inplace=True)
    df.drop(index=df.index[len(df)-1], axis=0, inplace=True)
    date = df.index
    df.reset_index(drop=True, inplace=True)
    df.tail()
    open_values=df['Open'].to_numpy()
    closed_values=df['Close'].to_numpy()
    date_values=date.to_numpy()



    #convert as an array will be used as feature in classifier
    data = df.to_numpy()
    #convert next closed data to array, will be used as label
    next_day_closed_values=next_day_closed.to_numpy()
    # dataset split and number of rows (history) involved in prediction
    test_split = 0.5
    history_points=100

    #normalized data
    data_normaliser = preprocessing.MinMaxScaler()
    #data=data.reshape(-1, 1)
    data_normalised = data_normaliser.fit_transform(data)
    next_day_closed_values = next_day_closed_values.reshape(-1, 1)
    next_day_closed_values_normalised = data_normaliser.fit_transform(next_day_closed_values)

    data_histories_normalised = np.array([data_normalised[i:i + history_points].copy() for i in range(len(data_normalised) - history_points)])
    n = 1558#int(data_histories_normalised.shape[0] * test_split)
    next_day_closed_values_normalised = np.array([next_day_closed_values_normalised[i + history_points].copy() for i in range(len(next_day_closed_values_normalised) - history_points)])
    next_day_closed_values = np.array([next_day_closed_values[i + history_points].copy() for i in range(len(next_day_closed_values) - history_points)])
    open_values = np.array([open_values[i + history_points].copy() for i in range(len(open_values) - history_points)])
    closed_values= np.array([closed_values[i + history_points].copy() for i in range(len(closed_values) - history_points)])
    date_values= np.array([date_values[i + history_points].copy() for i in range(len(date_values) - history_points)])

    # Generate 12x1 images from the rolling windows
    def create_images(data):
        images = []
        for i in range(len(data)):
            window = data[i]
            image = window.T
            #print(image.shape)
            if image.shape == (13, 100):
                images.append(image)
        return np.array(images)
    #

    images = create_images(data_histories_normalised)
    #print(len(images))
    #TRAIN DATA
    data_train = images[:n]#data_histories_normalised[:n]
    y_train = next_day_closed_values_normalised[:n]

    #TEST DATA
    data_test = images[n:]#data_histories_normalised[n:]
    y_test = next_day_closed_values_normalised[n:]
    #print(len(y_test))
    #print(len(data_test))
    # Reshape for CNN
    data_train = data_train.reshape(-1, 13, 1, 1)
    data_test = data_test.reshape(-1, 13, 1, 1)

    unscaled_y_test = next_day_closed_values[n:]
    unscaled_y=next_day_closed_values
    stacking = pd.DataFrame(columns=['date_time','open', 'close','delta_next_day', 'nextclose'])
    stacking['date_time'] = date_values
    stacking['open'] = open_values
    stacking['close'] = closed_values
    stacking['nextclose'] = next_day_closed


    lr=0.0001
    #CNN MODEL
    mse_=0
    nb_prediction=50
    for ii in range(0,nb_prediction,2):
        # Define CNN model
        model = Sequential()
        model.add(Conv2D(64, kernel_size=(3, 3), padding='same', input_shape=(100, 13, 1), kernel_regularizer=regularizers.l2(0.01)))
        model.add(BatchNormalization())
        #model.add(LeakyReLU(negative_slope=0.1))  # Use negative_slope instead of alpha
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))
        model.add(Conv2D(128, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
        model.add(BatchNormalization())
        #model.add(LeakyReLU(negative_slope=0.1))  # Use negative_slope instead of alpha
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.3))
        model.add(Conv2D(256, kernel_size=(2, 2), padding='same', kernel_regularizer=regularizers.l2(0.01)))
        model.add(BatchNormalization())
        #model.add(LeakyReLU(negative_slope=0.1))  # Use negative_slope instead of alpha
        model.add(Flatten())
        model.add(Dense(512, activation='relu'))
        model.add(Dropout(0.35))
        model.add(Dense(1, activation='linear'))

        # Compile the model
        nadam = optimizers.Nadam(learning_rate=ii*lr+lr)
        model.compile(optimizer=nadam, loss='mse')

        # Add early stopping and learning rate scheduler
        early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
        #reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

        # Train the model
        data_train=tf.reshape(data_train,(1558,100,13,1))
        model.fit(data_train, y_train, batch_size=64, epochs=25)

        # Test the model
        data_test=tf.reshape(data_test,(90,100,13,1))
        images=tf.reshape(images,(1648,100,13,1))
        # evaluation
        y_test_predicted = model.predict(data_test)
        y_test_predicted = data_normaliser.inverse_transform(y_test_predicted)
        y_predicted = model.predict(images)#data_histories_normalised)
        y_predicted = data_normaliser.inverse_transform(y_predicted)
        unscaled_y_test = np.reshape(unscaled_y_test, (-1, 1))
     #   print(unscaled_y_test.shape)
     #   print(y_test_predicted.shape)

        assert unscaled_y_test.shape == y_test_predicted.shape
        #real_mse = np.mean(np.square(unscaled_y_test - y_test_predicted))
        #mse=real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
        #scaled_mse = scaled_mse+real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
        print("Prediction: ",ii)
        #print('MSE:',tf.keras.losses.MSE(tf.expand_dims(srcTF, axis=-1) , tf.expand_dims(tgtTF, axis=-1)) )

        plt.gcf().set_size_inches(22, 15, forward=True)
        start = 0
        end = -1
        #real = plt.plot(unscaled_y_test[start:end], label='real')
        #pred = plt.plot(y_test_predicted[start:end], label='predicted')
        #real = plt.plot(unscaled_y[start:end], label='real')
        #pred = plt.plot(y_predicted[start:end], label='predicted')
        #plt.legend(['Real', 'Predicted'])
        #plt.show()
        #from datetime import datetime
        #model.save(f'basic_model.h5')

        #If next_day_closed_price is higher than today closed price for given threshold, then long or buy
        #If the difference is negative, short or sell, otherwise hold.
        thresh = 0.1
        hold_=0
        long_=1
        short_=2
        strategy=[]
        closed_price_today=[]
        for i in range (len(unscaled_y)):
            closed_price_today_=unscaled_y[i]
            closed_price_today.append(closed_price_today_)
            predicted_closed_price_tomorrow = y_predicted[i]
            delta=predicted_closed_price_tomorrow-closed_price_today_
            if delta > thresh:
                strategy.append(long_)
            elif delta < 0:
                strategy.append(short_)
            else:
                strategy.append(hold_)
        mse=mean_squared_error(next_day_closed_values, y_predicted)
        mse_=mse_+mse
        pt = datetime.datetime.now()-startCNNs_LSTMs
        total_seconds = pt.total_seconds()
        print('Step 1. Number_of_prediction: ',(ii+1),' Average_MSE: ',mse_/(ii+1),' Execution_time (s): ',total_seconds," Learning_rate:", ii*lr+lr)
        S='prediction_'+str(ii)
        stacking[S] = strategy

    #stacking['delta_next_day'] = next_day_closed_values-y_predicted
    #stacking['nextclose']=y_predicted#stacking.drop['nextclose'], axis=1, inplace=True)
    #stacking.to_csv('LSTM_CNNs.csv')


    #start with LSTM

    #convert as an array will be used as feature in classifier
    data = df.to_numpy()
    #convert next closed data to array, will be used as label
    next_day_closed_values=next_day_closed.to_numpy()
    # dataset split and number of rows (history) involved in prediction
    test_split = 0.5
    history_points=100

    #normalized data
    data_normaliser = preprocessing.MinMaxScaler()
    #data=data.reshape(-1, 1)
    data_normalised = data_normaliser.fit_transform(data)
    next_day_closed_values = next_day_closed_values.reshape(-1, 1)
    next_day_closed_values_normalised = data_normaliser.fit_transform(next_day_closed_values)

    data_histories_normalised = np.array([data_normalised[i:i + history_points].copy() for i in range(len(data_normalised) - history_points)])
    n = 1558#int(data_histories_normalised.shape[0] * test_split)
    next_day_closed_values_normalised = np.array([next_day_closed_values_normalised[i + history_points].copy() for i in range(len(next_day_closed_values_normalised) - history_points)])
    next_day_closed_values = np.array([next_day_closed_values[i + history_points].copy() for i in range(len(next_day_closed_values) - history_points)])
    open_values = np.array([open_values[i + history_points].copy() for i in range(len(open_values) - history_points)])
    closed_values= np.array([closed_values[i + history_points].copy() for i in range(len(closed_values) - history_points)])
    date_values= np.array([date_values[i + history_points].copy() for i in range(len(date_values) - history_points)])

    #TRAIN DATA
    data_train = data_histories_normalised[:n]
    y_train = next_day_closed_values_normalised[:n]

    #TEST DATA
    data_test = data_histories_normalised[n:]
    y_test = next_day_closed_values_normalised[n:]

    unscaled_y_test = next_day_closed_values[n:]
    unscaled_y=next_day_closed_values
    #stacking = pd.DataFrame(columns=['date_time','open', 'close','delta_next_day', 'nextclose'])
    #stacking['date_time'] = date_values
    #stacking['open'] = open_values
    #stacking['close'] = closed_values
    #stacking['nextclose'] = next_day_closed


    for ii in range(1,nb_prediction,2):
        # model architecture
        lstm_input = Input(shape=(history_points, 13), name='lstm_input')
        x = LSTM(50, name='lstm_0')(lstm_input)
        x = Dropout(0.2, name='lstm_dropout_0')(x)
        x = Dense(64, name='dense_0')(x)
        x = Activation('sigmoid', name='sigmoid_0')(x)
        x = Dense(1, name='dense_1')(x)
        output = Activation('linear', name='linear_output')(x)

        model = Model(inputs=lstm_input, outputs=output)
        adam = optimizers.Adam(learning_rate=ii*lr+lr)
        model.compile(optimizer=adam, loss='mse')
        #print(len(data_train))
        #print(len(y_train))

        model.fit(x=data_train, y=y_train, batch_size=32, epochs=25, shuffle=True, validation_split=0.1)

        # evaluation
        y_test_predicted = model.predict(data_test)
        y_test_predicted = data_normaliser.inverse_transform(y_test_predicted)
        y_predicted = model.predict(data_histories_normalised)
        y_predicted = data_normaliser.inverse_transform(y_predicted)
        unscaled_y_test = np.reshape(unscaled_y_test, (-1, 1))
        #   print(unscaled_y_test.shape)
     #   print(y_test_predicted.shape)

        assert unscaled_y_test.shape == y_test_predicted.shape
        #real_mse = np.mean(np.square(unscaled_y_test - y_test_predicted))
        #mse=real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
        #scaled_mse = scaled_mse+real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
        #print("Prediction: ",ii)
        #print('MSE:',tf.keras.losses.MSE(tf.expand_dims(srcTF, axis=-1) , tf.expand_dims(tgtTF, axis=-1)) )

        plt.gcf().set_size_inches(22, 15, forward=True)
        start = 0
        end = -1
        #real = plt.plot(unscaled_y_test[start:end], label='real')
        #pred = plt.plot(y_test_predicted[start:end], label='predicted')
        #real = plt.plot(unscaled_y[start:end], label='real')
        #pred = plt.plot(y_predicted[start:end], label='predicted')
        #plt.legend(['Real', 'Predicted'])
        #plt.show()
        #from datetime import datetime
        #model.save(f'basic_model.h5')

        #If next_day_closed_price is higher than today closed price for given threshold, then long or buy
        #If the difference is negative, short or sell, otherwise hold.
        thresh = 0.1
        hold_=0
        long_=1
        short_=2
        strategy=[]
        closed_price_today=[]
        for i in range (len(unscaled_y)):
            closed_price_today_=unscaled_y[i]
            closed_price_today.append(closed_price_today_)
            predicted_closed_price_tomorrow = y_predicted[i]
            delta=predicted_closed_price_tomorrow-closed_price_today_
            if delta > thresh:
                strategy.append(long_)
            elif delta < 0:
                strategy.append(short_)
            else:
                strategy.append(hold_)
        mse=mean_squared_error(next_day_closed_values, y_predicted)
        mse_=mse_+mse
        pt = datetime.datetime.now()-startCNNs_LSTMs
        total_seconds = pt.total_seconds()
        print('Step 1. Number_of_prediction: ',(ii+1),' Average_MSE: ',mse_/(ii+1),' Execution_time (s): ',total_seconds," Learning_rate:", ii*lr+lr)
        S='prediction_'+str(ii)
        stacking[S] = strategy
        print(datetime.datetime.now()-startCNNs_LSTMs)

    stacking['delta_next_day'] = next_day_closed_values-y_predicted
    stacking['nextclose']=y_predicted#stacking.drop['nextclose'], axis=1, inplace=True)
    stacking.to_csv('CNNs_LSTMs.csv')

    today = plt.plot(next_day_closed_values, label='Tomorrow')
    tomorrow = plt.plot(y_predicted, label='Tomorrow_Predicted')
    plt.legend(['Tomorrow', 'Tomorrow_Predicted_CNNs_LSTMs'])

    plt.show()

    
# Create a socket object
client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
host = socket.gethostname()  # Get local machine name
port = 12345  # Reserve a port for your service

client_socket.connect((host, port))

with open('distCNNs_LSTMs1.csv', 'rb') as f:
    print("Sending file...")
    while True:
        data = f.read(1024)
        if not data:
            break
        client_socket.send(data)
    print("File sent successfully")

client_socket.close()
# Out:
# Standby for prediction order
# Receive prediction order
# [*********************100%***********************]  1 of 1 completed
# C:\Users\USER\anaconda3\lib\site-packages\yfinance\utils.py:681: FutureWarning: The 'unit' keyword in TimedeltaIndex construction is deprecated and will be removed in a future version. Use pd.to_timedelta instead.
#   df.index += _pd.TimedeltaIndex(dst_error_hours, 'h')
# Stacking stage:
# Epoch 1/25
# 44/44 [==============================] - 7s 90ms/step - loss: 0.0175 - val_loss: 0.0604
# Epoch 2/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0020 - val_loss: 0.0195
# Epoch 3/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0012 - val_loss: 0.0089
# Epoch 4/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0011 - val_loss: 0.0071
# Epoch 5/25
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0010 - val_loss: 0.0070
# Epoch 6/25
# 44/44 [==============================] - 3s 59ms/step - loss: 9.4873e-04 - val_loss: 0.0065
# Epoch 7/25
# 44/44 [==============================] - 3s 58ms/step - loss: 8.6455e-04 - val_loss: 0.0046
# Epoch 8/25
# 44/44 [==============================] - 3s 57ms/step - loss: 9.0910e-04 - val_loss: 0.0037
# Epoch 9/25
# 44/44 [==============================] - 3s 57ms/step - loss: 8.1343e-04 - val_loss: 0.0041
# Epoch 10/25
# 44/44 [==============================] - 2s 56ms/step - loss: 7.0416e-04 - val_loss: 0.0025
# Epoch 11/25
# 44/44 [==============================] - 3s 58ms/step - loss: 6.8524e-04 - val_loss: 0.0046
# Epoch 12/25
# 44/44 [==============================] - 2s 57ms/step - loss: 6.3784e-04 - val_loss: 0.0037
# Epoch 13/25
# 44/44 [==============================] - 2s 56ms/step - loss: 6.3686e-04 - val_loss: 0.0034
# Epoch 14/25
# 44/44 [==============================] - 2s 56ms/step - loss: 6.5376e-04 - val_loss: 0.0022
# Epoch 15/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.6261e-04 - val_loss: 0.0016
# Epoch 16/25
# 44/44 [==============================] - 3s 71ms/step - loss: 5.8526e-04 - val_loss: 0.0017
# Epoch 17/25
# 44/44 [==============================] - 3s 69ms/step - loss: 5.8603e-04 - val_loss: 0.0027
# Epoch 18/25
# 44/44 [==============================] - 3s 71ms/step - loss: 6.2321e-04 - val_loss: 0.0021
# Epoch 19/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.8553e-04 - val_loss: 7.9312e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.9771e-04 - val_loss: 7.7468e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.8882e-04 - val_loss: 0.0018
# Epoch 22/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.1225e-04 - val_loss: 0.0010
# Epoch 23/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.5377e-04 - val_loss: 0.0016
# Epoch 24/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.9332e-04 - val_loss: 0.0012
# Epoch 25/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.8762e-04 - val_loss: 0.0014
# 4/4 [==============================] - 1s 20ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  1
# Step 1. Number_of_prediction:  2  Average_MSE:  2.0534433787077244  Execution_time (s):  73.134425  Learning_rate: 0.0002
# 0:01:13.136089
# Epoch 1/25
# 44/44 [==============================] - 7s 65ms/step - loss: 0.2933 - val_loss: 0.6122
# Epoch 2/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0393 - val_loss: 0.2891
# Epoch 3/25
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0144 - val_loss: 0.0280
# Epoch 4/25
# 44/44 [==============================] - 2s 54ms/step - loss: 0.0042 - val_loss: 0.0226
# Epoch 5/25
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0032 - val_loss: 0.0208
# Epoch 6/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0031 - val_loss: 0.0182
# Epoch 7/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0026 - val_loss: 0.0188
# Epoch 8/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0025 - val_loss: 0.0223
# Epoch 9/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0021 - val_loss: 0.0128
# Epoch 10/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0020 - val_loss: 0.0101
# Epoch 11/25
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0019 - val_loss: 0.0104
# Epoch 12/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0018 - val_loss: 0.0102
# Epoch 13/25
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0016 - val_loss: 0.0105
# Epoch 14/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0016 - val_loss: 0.0112
# Epoch 15/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0015 - val_loss: 0.0082
# Epoch 16/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0014 - val_loss: 0.0071
# Epoch 17/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0013 - val_loss: 0.0073
# Epoch 18/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0013 - val_loss: 0.0063
# Epoch 19/25
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0011 - val_loss: 0.0059
# Epoch 20/25
# 44/44 [==============================] - 2s 54ms/step - loss: 0.0012 - val_loss: 0.0066
# Epoch 21/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0011 - val_loss: 0.0063
# Epoch 22/25
# 44/44 [==============================] - 2s 53ms/step - loss: 9.9984e-04 - val_loss: 0.0045
# Epoch 23/25
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0010 - val_loss: 0.0064
# Epoch 24/25
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0011 - val_loss: 0.0057
# Epoch 25/25
# 44/44 [==============================] - 2s 56ms/step - loss: 9.4437e-04 - val_loss: 0.0043
# 4/4 [==============================] - 2s 22ms/step
# 53/53 [==============================] - 1s 26ms/step
# Prediction:  3
# Step 1. Number_of_prediction:  4  Average_MSE:  3.9290577695733617  Execution_time (s):  139.476876  Learning_rate: 0.0004
# 0:02:19.476876
# Epoch 1/25
# 44/44 [==============================] - 8s 79ms/step - loss: 0.0470 - val_loss: 0.0496
# Epoch 2/25
# 44/44 [==============================] - 3s 69ms/step - loss: 0.0021 - val_loss: 0.0124
# Epoch 3/25
# 44/44 [==============================] - 3s 57ms/step - loss: 0.0012 - val_loss: 0.0079
# Epoch 4/25
# 44/44 [==============================] - 2s 54ms/step - loss: 0.0013 - val_loss: 0.0053
# Epoch 5/25
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 6/25
# 44/44 [==============================] - 2s 55ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 7/25
# 44/44 [==============================] - 2s 55ms/step - loss: 9.2100e-04 - val_loss: 0.0019
# Epoch 8/25
# 44/44 [==============================] - 2s 54ms/step - loss: 9.3105e-04 - val_loss: 0.0010
# Epoch 9/25
# 44/44 [==============================] - 2s 54ms/step - loss: 8.4166e-04 - val_loss: 0.0018
# Epoch 10/25
# 44/44 [==============================] - 2s 55ms/step - loss: 7.7465e-04 - val_loss: 9.4614e-04
# Epoch 11/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.9833e-04 - val_loss: 9.4860e-04
# Epoch 12/25
# 44/44 [==============================] - 2s 55ms/step - loss: 7.2591e-04 - val_loss: 0.0019
# Epoch 13/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.5090e-04 - val_loss: 8.2938e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 57ms/step - loss: 6.4664e-04 - val_loss: 7.3628e-04
# Epoch 15/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.7823e-04 - val_loss: 7.5742e-04
# Epoch 16/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.1211e-04 - val_loss: 7.4484e-04
# Epoch 17/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.1575e-04 - val_loss: 0.0012
# Epoch 18/25
# 44/44 [==============================] - 3s 59ms/step - loss: 6.3817e-04 - val_loss: 0.0014
# Epoch 19/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.9052e-04 - val_loss: 6.6370e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.6811e-04 - val_loss: 7.8268e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.9539e-04 - val_loss: 7.0427e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.2545e-04 - val_loss: 6.2475e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.1964e-04 - val_loss: 0.0012
# Epoch 24/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.1555e-04 - val_loss: 7.3701e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.9066e-04 - val_loss: 8.2316e-04
# 4/4 [==============================] - 2s 22ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  5
# Step 1. Number_of_prediction:  6  Average_MSE:  3.0671117402979218  Execution_time (s):  210.330791  Learning_rate: 0.0006000000000000001
# 0:03:30.330791
# Epoch 1/25
# 44/44 [==============================] - 7s 70ms/step - loss: 0.0844 - val_loss: 0.0597
# Epoch 2/25
# 44/44 [==============================] - 2s 54ms/step - loss: 0.0023 - val_loss: 0.0064
# Epoch 3/25
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 4/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0011 - val_loss: 0.0025
# Epoch 5/25
# 44/44 [==============================] - 2s 54ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 6/25
# 44/44 [==============================] - 3s 58ms/step - loss: 9.8555e-04 - val_loss: 9.3468e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 60ms/step - loss: 8.2481e-04 - val_loss: 0.0012
# Epoch 8/25
# 44/44 [==============================] - 2s 55ms/step - loss: 8.7346e-04 - val_loss: 9.1084e-04
# Epoch 9/25
# 44/44 [==============================] - 2s 55ms/step - loss: 7.3580e-04 - val_loss: 9.1504e-04
# Epoch 10/25
# 44/44 [==============================] - 2s 56ms/step - loss: 7.1947e-04 - val_loss: 8.7788e-04
# Epoch 11/25
# 44/44 [==============================] - 2s 55ms/step - loss: 7.7597e-04 - val_loss: 0.0023
# Epoch 12/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.8138e-04 - val_loss: 0.0016
# Epoch 13/25
# 44/44 [==============================] - 2s 53ms/step - loss: 6.8073e-04 - val_loss: 0.0011
# Epoch 14/25
# 44/44 [==============================] - 2s 54ms/step - loss: 6.5048e-04 - val_loss: 0.0010
# Epoch 15/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.6253e-04 - val_loss: 7.2278e-04
# Epoch 16/25
# 44/44 [==============================] - 2s 51ms/step - loss: 6.5163e-04 - val_loss: 6.5394e-04
# Epoch 17/25
# 44/44 [==============================] - 2s 53ms/step - loss: 6.1250e-04 - val_loss: 0.0013
# Epoch 18/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.8142e-04 - val_loss: 0.0015
# Epoch 19/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.9317e-04 - val_loss: 6.7794e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 56ms/step - loss: 6.0505e-04 - val_loss: 6.3671e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.1206e-04 - val_loss: 7.5657e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.4937e-04 - val_loss: 7.6308e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.7206e-04 - val_loss: 0.0023
# Epoch 24/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.9682e-04 - val_loss: 0.0012
# Epoch 25/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.9915e-04 - val_loss: 0.0014
# 4/4 [==============================] - 1s 23ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  7
# Step 1. Number_of_prediction:  8  Average_MSE:  2.7633374852089085  Execution_time (s):  278.897509  Learning_rate: 0.0008
# 0:04:38.898739
# Epoch 1/25
# 44/44 [==============================] - 6s 64ms/step - loss: 0.1502 - val_loss: 0.2820
# Epoch 2/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0122 - val_loss: 0.0495
# Epoch 3/25
# 44/44 [==============================] - 2s 50ms/step - loss: 0.0025 - val_loss: 0.0191
# Epoch 4/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0018 - val_loss: 0.0125
# Epoch 5/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0013 - val_loss: 0.0046
# Epoch 6/25
# 44/44 [==============================] - 2s 53ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 7/25
# 44/44 [==============================] - 2s 54ms/step - loss: 0.0010 - val_loss: 0.0056
# Epoch 8/25
# 44/44 [==============================] - 2s 52ms/step - loss: 0.0011 - val_loss: 0.0034
# Epoch 9/25
# 44/44 [==============================] - 2s 54ms/step - loss: 8.4010e-04 - val_loss: 0.0038
# Epoch 10/25
# 44/44 [==============================] - 2s 53ms/step - loss: 8.4163e-04 - val_loss: 0.0013
# Epoch 11/25
# 44/44 [==============================] - 2s 54ms/step - loss: 7.4676e-04 - val_loss: 0.0022
# Epoch 12/25
# 44/44 [==============================] - 2s 55ms/step - loss: 7.1219e-04 - val_loss: 0.0050
# Epoch 13/25
# 44/44 [==============================] - 2s 54ms/step - loss: 8.0338e-04 - val_loss: 0.0016
# Epoch 14/25
# 44/44 [==============================] - 2s 55ms/step - loss: 7.1272e-04 - val_loss: 0.0010
# Epoch 15/25
# 44/44 [==============================] - 2s 53ms/step - loss: 6.7626e-04 - val_loss: 0.0019
# Epoch 16/25
# 44/44 [==============================] - 2s 54ms/step - loss: 6.8470e-04 - val_loss: 0.0054
# Epoch 17/25
# 44/44 [==============================] - 2s 50ms/step - loss: 7.0715e-04 - val_loss: 0.0026
# Epoch 18/25
# 44/44 [==============================] - 2s 49ms/step - loss: 6.5685e-04 - val_loss: 0.0022
# Epoch 19/25
# 44/44 [==============================] - 2s 49ms/step - loss: 6.1742e-04 - val_loss: 0.0011
# Epoch 20/25
# 44/44 [==============================] - 3s 62ms/step - loss: 5.7068e-04 - val_loss: 0.0017
# Epoch 21/25
# 44/44 [==============================] - 3s 61ms/step - loss: 5.2942e-04 - val_loss: 0.0010
# Epoch 22/25
# 44/44 [==============================] - 3s 65ms/step - loss: 5.8958e-04 - val_loss: 0.0017
# Epoch 23/25
# 44/44 [==============================] - 3s 60ms/step - loss: 6.3329e-04 - val_loss: 0.0014
# Epoch 24/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.4517e-04 - val_loss: 0.0017
# Epoch 25/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.4134e-04 - val_loss: 7.3367e-04
# 4/4 [==============================] - 1s 19ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  9
# Step 1. Number_of_prediction:  10  Average_MSE:  2.4979837842638837  Execution_time (s):  346.605026  Learning_rate: 0.001
# 0:05:46.606541
# Epoch 1/25
# 44/44 [==============================] - 8s 70ms/step - loss: 0.0105 - val_loss: 0.0110
# Epoch 2/25
# 44/44 [==============================] - 2s 47ms/step - loss: 0.0010 - val_loss: 0.0094
# Epoch 3/25
# 44/44 [==============================] - 2s 49ms/step - loss: 7.8446e-04 - val_loss: 0.0030
# Epoch 4/25
# 44/44 [==============================] - 2s 56ms/step - loss: 6.4414e-04 - val_loss: 0.0025
# Epoch 5/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.7908e-04 - val_loss: 0.0018
# Epoch 6/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.6946e-04 - val_loss: 0.0020
# Epoch 7/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.4403e-04 - val_loss: 0.0030
# Epoch 8/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.2424e-04 - val_loss: 9.6574e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.0879e-04 - val_loss: 0.0016
# Epoch 10/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.8469e-04 - val_loss: 7.3664e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.1587e-04 - val_loss: 6.2240e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.9091e-04 - val_loss: 0.0020
# Epoch 13/25
# 44/44 [==============================] - 3s 62ms/step - loss: 5.2052e-04 - val_loss: 6.0428e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.1755e-04 - val_loss: 6.4405e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 63ms/step - loss: 3.8407e-04 - val_loss: 6.0567e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.0251e-04 - val_loss: 8.3467e-04
# Epoch 17/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.0638e-04 - val_loss: 6.1306e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.4614e-04 - val_loss: 0.0024
# Epoch 19/25
# 44/44 [==============================] - 3s 64ms/step - loss: 3.7526e-04 - val_loss: 5.8064e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.0096e-04 - val_loss: 5.8359e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.5239e-04 - val_loss: 8.7494e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.7990e-04 - val_loss: 5.8905e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 63ms/step - loss: 3.9165e-04 - val_loss: 5.7582e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.8773e-04 - val_loss: 7.2328e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.2905e-04 - val_loss: 7.1292e-04
# 4/4 [==============================] - 1s 22ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  11
# Step 1. Number_of_prediction:  12  Average_MSE:  2.348452777903607  Execution_time (s):  421.091095  Learning_rate: 0.0012000000000000001
# 0:07:01.091095
# Epoch 1/25
# 44/44 [==============================] - 10s 71ms/step - loss: 0.1242 - val_loss: 0.2044
# Epoch 2/25
# 44/44 [==============================] - 2s 50ms/step - loss: 0.0048 - val_loss: 0.0262
# Epoch 3/25
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 4/25
# 44/44 [==============================] - 3s 61ms/step - loss: 0.0010 - val_loss: 0.0045
# Epoch 5/25
# 44/44 [==============================] - 2s 54ms/step - loss: 8.3992e-04 - val_loss: 0.0018
# Epoch 6/25
# 44/44 [==============================] - 3s 58ms/step - loss: 8.8252e-04 - val_loss: 0.0016
# Epoch 7/25
# 44/44 [==============================] - 3s 61ms/step - loss: 7.6001e-04 - val_loss: 0.0018
# Epoch 8/25
# 44/44 [==============================] - 3s 61ms/step - loss: 7.8163e-04 - val_loss: 0.0010
# Epoch 9/25
# 44/44 [==============================] - 3s 60ms/step - loss: 7.3540e-04 - val_loss: 0.0049
# Epoch 10/25
# 44/44 [==============================] - 3s 58ms/step - loss: 7.5554e-04 - val_loss: 9.5572e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.5624e-04 - val_loss: 8.1723e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 57ms/step - loss: 6.3589e-04 - val_loss: 8.6031e-04
# Epoch 13/25
# 44/44 [==============================] - 2s 57ms/step - loss: 6.2330e-04 - val_loss: 9.7779e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.9572e-04 - val_loss: 0.0012
# Epoch 15/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.2720e-04 - val_loss: 9.6128e-04
# Epoch 16/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.1448e-04 - val_loss: 0.0021
# Epoch 17/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.1058e-04 - val_loss: 8.7815e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.8787e-04 - val_loss: 8.6661e-04
# Epoch 19/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.3612e-04 - val_loss: 7.7280e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.9117e-04 - val_loss: 7.5715e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.4845e-04 - val_loss: 7.2464e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.2376e-04 - val_loss: 0.0010
# Epoch 23/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.5075e-04 - val_loss: 7.1210e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.1371e-04 - val_loss: 0.0012
# Epoch 25/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.5493e-04 - val_loss: 7.1534e-04
# 4/4 [==============================] - 1s 18ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  13
# Step 1. Number_of_prediction:  14  Average_MSE:  2.2189253875210073  Execution_time (s):  494.46895  Learning_rate: 0.0014000000000000002
# 0:08:14.473025
# Epoch 1/25
# 44/44 [==============================] - 8s 67ms/step - loss: 0.0278 - val_loss: 0.0088
# Epoch 2/25
# 44/44 [==============================] - 2s 50ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 3/25
# 44/44 [==============================] - 2s 48ms/step - loss: 7.6337e-04 - val_loss: 0.0020
# Epoch 4/25
# 44/44 [==============================] - 3s 62ms/step - loss: 7.1512e-04 - val_loss: 6.7586e-04
# Epoch 5/25
# 44/44 [==============================] - 2s 53ms/step - loss: 6.3095e-04 - val_loss: 0.0012
# Epoch 6/25
# 44/44 [==============================] - 3s 59ms/step - loss: 6.0924e-04 - val_loss: 8.7495e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 69ms/step - loss: 5.8100e-04 - val_loss: 0.0023
# Epoch 8/25
# 44/44 [==============================] - 3s 70ms/step - loss: 6.1472e-04 - val_loss: 6.9885e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 65ms/step - loss: 5.3862e-04 - val_loss: 0.0018
# Epoch 10/25
# 44/44 [==============================] - 3s 73ms/step - loss: 4.9920e-04 - val_loss: 7.7138e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.5568e-04 - val_loss: 7.7095e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 62ms/step - loss: 5.0360e-04 - val_loss: 0.0014
# Epoch 13/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.9887e-04 - val_loss: 5.7540e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 65ms/step - loss: 4.4760e-04 - val_loss: 5.6623e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 63ms/step - loss: 3.9073e-04 - val_loss: 6.0679e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.2606e-04 - val_loss: 0.0015
# Epoch 17/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.0133e-04 - val_loss: 6.3476e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.7997e-04 - val_loss: 0.0028
# Epoch 19/25
# 44/44 [==============================] - 3s 65ms/step - loss: 4.2984e-04 - val_loss: 5.7934e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.3231e-04 - val_loss: 6.1380e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 63ms/step - loss: 3.5907e-04 - val_loss: 5.7060e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.8384e-04 - val_loss: 5.6827e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.0551e-04 - val_loss: 8.7253e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.0664e-04 - val_loss: 5.9204e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.4956e-04 - val_loss: 5.4110e-04
# 4/4 [==============================] - 2s 26ms/step
# 53/53 [==============================] - 1s 23ms/step
# Prediction:  15
# Step 1. Number_of_prediction:  16  Average_MSE:  2.076552201282398  Execution_time (s):  572.651249  Learning_rate: 0.0016
# 0:09:32.653708
# Epoch 1/25
# 44/44 [==============================] - 9s 64ms/step - loss: 0.0516 - val_loss: 0.0169
# Epoch 2/25
# 44/44 [==============================] - 2s 46ms/step - loss: 0.0015 - val_loss: 0.0112
# Epoch 3/25
# 44/44 [==============================] - 2s 45ms/step - loss: 8.6900e-04 - val_loss: 0.0037
# Epoch 4/25
# 44/44 [==============================] - 3s 60ms/step - loss: 8.4507e-04 - val_loss: 0.0063
# Epoch 5/25
# 44/44 [==============================] - 2s 54ms/step - loss: 8.5220e-04 - val_loss: 0.0010
# Epoch 6/25
# 44/44 [==============================] - 3s 60ms/step - loss: 7.3038e-04 - val_loss: 0.0020
# Epoch 7/25
# 44/44 [==============================] - 3s 67ms/step - loss: 6.1661e-04 - val_loss: 0.0061
# Epoch 8/25
# 44/44 [==============================] - 3s 60ms/step - loss: 6.9430e-04 - val_loss: 0.0012
# Epoch 9/25
# 44/44 [==============================] - 3s 60ms/step - loss: 6.4171e-04 - val_loss: 0.0025
# Epoch 10/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.4201e-04 - val_loss: 7.7821e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.7629e-04 - val_loss: 6.1555e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.9455e-04 - val_loss: 0.0016
# Epoch 13/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.4520e-04 - val_loss: 8.4231e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.4095e-04 - val_loss: 6.0276e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 64ms/step - loss: 3.8388e-04 - val_loss: 6.0395e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.4322e-04 - val_loss: 0.0021
# Epoch 17/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.4960e-04 - val_loss: 6.6627e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.9866e-04 - val_loss: 0.0026
# Epoch 19/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.2797e-04 - val_loss: 7.5561e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 74ms/step - loss: 4.3487e-04 - val_loss: 5.9543e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 62ms/step - loss: 3.6445e-04 - val_loss: 7.4678e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.0657e-04 - val_loss: 6.8046e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.1517e-04 - val_loss: 0.0011
# Epoch 24/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.0106e-04 - val_loss: 5.7995e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.4748e-04 - val_loss: 8.0400e-04
# 4/4 [==============================] - 1s 24ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  17
# Step 1. Number_of_prediction:  18  Average_MSE:  1.9884250414312135  Execution_time (s):  649.565038  Learning_rate: 0.0018000000000000002
# 0:10:49.568020
# Epoch 1/25
# 44/44 [==============================] - 9s 73ms/step - loss: 0.0916 - val_loss: 0.0435
# Epoch 2/25
# 44/44 [==============================] - 2s 48ms/step - loss: 0.0020 - val_loss: 0.0038
# Epoch 3/25
# 44/44 [==============================] - 2s 48ms/step - loss: 9.5420e-04 - val_loss: 0.0034
# Epoch 4/25
# 44/44 [==============================] - 3s 62ms/step - loss: 9.0560e-04 - val_loss: 0.0015
# Epoch 5/25
# 44/44 [==============================] - 3s 58ms/step - loss: 8.5084e-04 - val_loss: 0.0012
# Epoch 6/25
# 44/44 [==============================] - 3s 61ms/step - loss: 8.0635e-04 - val_loss: 9.2365e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 59ms/step - loss: 8.0337e-04 - val_loss: 0.0013
# Epoch 8/25
# 44/44 [==============================] - 3s 58ms/step - loss: 7.3894e-04 - val_loss: 8.5804e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 57ms/step - loss: 6.8894e-04 - val_loss: 7.4205e-04
# Epoch 10/25
# 44/44 [==============================] - 3s 59ms/step - loss: 7.5269e-04 - val_loss: 9.3995e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.5295e-04 - val_loss: 0.0013
# Epoch 12/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.7580e-04 - val_loss: 0.0021
# Epoch 13/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.7110e-04 - val_loss: 0.0015
# Epoch 14/25
# 44/44 [==============================] - 3s 67ms/step - loss: 5.8330e-04 - val_loss: 0.0012
# Epoch 15/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.9352e-04 - val_loss: 6.2499e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.0930e-04 - val_loss: 0.0014
# Epoch 17/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.0626e-04 - val_loss: 8.2216e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.6244e-04 - val_loss: 0.0022
# Epoch 19/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.2039e-04 - val_loss: 6.7090e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.8186e-04 - val_loss: 0.0012
# Epoch 21/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.0405e-04 - val_loss: 6.8169e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.5193e-04 - val_loss: 6.0163e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.1662e-04 - val_loss: 6.1812e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.6013e-04 - val_loss: 7.4789e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.8531e-04 - val_loss: 8.1936e-04
# 4/4 [==============================] - 2s 23ms/step
# 53/53 [==============================] - 1s 24ms/step
# Prediction:  19
# Step 1. Number_of_prediction:  20  Average_MSE:  1.9260054391196615  Execution_time (s):  725.738375  Learning_rate: 0.002
# 0:12:05.740179
# Epoch 1/25
# 44/44 [==============================] - 10s 91ms/step - loss: 0.0066 - val_loss: 0.0016
# Epoch 2/25
# 44/44 [==============================] - 2s 53ms/step - loss: 8.4504e-04 - val_loss: 0.0016
# Epoch 3/25
# 44/44 [==============================] - 2s 53ms/step - loss: 6.0157e-04 - val_loss: 7.5886e-04
# Epoch 4/25
# 44/44 [==============================] - 2s 49ms/step - loss: 5.3316e-04 - val_loss: 5.9819e-04
# Epoch 5/25
# 44/44 [==============================] - 2s 49ms/step - loss: 5.7136e-04 - val_loss: 8.5441e-04
# Epoch 6/25
# 44/44 [==============================] - 2s 52ms/step - loss: 5.6198e-04 - val_loss: 5.8061e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.6315e-04 - val_loss: 0.0035
# Epoch 8/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.9066e-04 - val_loss: 6.0469e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.3855e-04 - val_loss: 0.0025
# Epoch 10/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.3971e-04 - val_loss: 0.0012
# Epoch 11/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.5913e-04 - val_loss: 0.0011
# Epoch 12/25
# 44/44 [==============================] - 3s 63ms/step - loss: 3.8640e-04 - val_loss: 0.0026
# Epoch 13/25
# 44/44 [==============================] - 3s 65ms/step - loss: 3.9013e-04 - val_loss: 7.3466e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.1497e-04 - val_loss: 7.0795e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 62ms/step - loss: 3.2663e-04 - val_loss: 5.3204e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 62ms/step - loss: 3.8869e-04 - val_loss: 9.2349e-04
# Epoch 17/25
# 44/44 [==============================] - 3s 67ms/step - loss: 3.7238e-04 - val_loss: 7.6224e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 72ms/step - loss: 4.3981e-04 - val_loss: 0.0023
# Epoch 19/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.1398e-04 - val_loss: 7.6672e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.4457e-04 - val_loss: 0.0010
# Epoch 21/25
# 44/44 [==============================] - 3s 64ms/step - loss: 3.4359e-04 - val_loss: 8.2360e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 64ms/step - loss: 3.5811e-04 - val_loss: 4.9609e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 71ms/step - loss: 3.9076e-04 - val_loss: 5.2970e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 66ms/step - loss: 4.3111e-04 - val_loss: 4.8848e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 70ms/step - loss: 3.4730e-04 - val_loss: 8.5888e-04
# 4/4 [==============================] - 2s 24ms/step
# 53/53 [==============================] - 1s 24ms/step
# Prediction:  21
# Step 1. Number_of_prediction:  22  Average_MSE:  1.8612274509549274  Execution_time (s):  804.863753  Learning_rate: 0.0022
# 0:13:24.867052
# Epoch 1/25
# 44/44 [==============================] - 14s 108ms/step - loss: 0.3703 - val_loss: 0.1557
# Epoch 2/25
# 44/44 [==============================] - 3s 57ms/step - loss: 0.0115 - val_loss: 0.0390
# Epoch 3/25
# 44/44 [==============================] - 2s 50ms/step - loss: 0.0045 - val_loss: 0.0160
# Epoch 4/25
# 44/44 [==============================] - 2s 49ms/step - loss: 0.0035 - val_loss: 0.0126
# Epoch 5/25
# 44/44 [==============================] - 2s 51ms/step - loss: 0.0029 - val_loss: 0.0074
# Epoch 6/25
# 44/44 [==============================] - 3s 58ms/step - loss: 0.0023 - val_loss: 0.0083
# Epoch 7/25
# 44/44 [==============================] - 3s 60ms/step - loss: 0.0019 - val_loss: 0.0084
# Epoch 8/25
# 44/44 [==============================] - 3s 64ms/step - loss: 0.0015 - val_loss: 0.0055
# Epoch 9/25
# 44/44 [==============================] - 3s 62ms/step - loss: 0.0014 - val_loss: 0.0057
# Epoch 10/25
# 44/44 [==============================] - 3s 65ms/step - loss: 0.0012 - val_loss: 0.0039
# Epoch 11/25
# 44/44 [==============================] - 3s 65ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 12/25
# 44/44 [==============================] - 3s 64ms/step - loss: 0.0010 - val_loss: 0.0047
# Epoch 13/25
# 44/44 [==============================] - 3s 65ms/step - loss: 9.2068e-04 - val_loss: 0.0041
# Epoch 14/25
# 44/44 [==============================] - 3s 63ms/step - loss: 8.1106e-04 - val_loss: 0.0028
# Epoch 15/25
# 44/44 [==============================] - 3s 64ms/step - loss: 7.0632e-04 - val_loss: 0.0022
# Epoch 16/25
# 44/44 [==============================] - 3s 68ms/step - loss: 7.2056e-04 - val_loss: 0.0035
# Epoch 17/25
# 44/44 [==============================] - 3s 75ms/step - loss: 7.1355e-04 - val_loss: 0.0031
# Epoch 18/25
# 44/44 [==============================] - 3s 63ms/step - loss: 7.1915e-04 - val_loss: 0.0031
# Epoch 19/25
# 44/44 [==============================] - 3s 64ms/step - loss: 6.4897e-04 - val_loss: 0.0015
# Epoch 20/25
# 44/44 [==============================] - 3s 64ms/step - loss: 6.5780e-04 - val_loss: 0.0014
# Epoch 21/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.7489e-04 - val_loss: 0.0020
# Epoch 22/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.8014e-04 - val_loss: 0.0013
# Epoch 23/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.3551e-04 - val_loss: 0.0023
# Epoch 24/25
# 44/44 [==============================] - 3s 62ms/step - loss: 5.5201e-04 - val_loss: 0.0017
# Epoch 25/25
# 44/44 [==============================] - 3s 65ms/step - loss: 5.2802e-04 - val_loss: 0.0017
# 4/4 [==============================] - 1s 21ms/step
# 53/53 [==============================] - 1s 23ms/step
# Prediction:  23
# Step 1. Number_of_prediction:  24  Average_MSE:  1.9112235418342258  Execution_time (s):  889.524518  Learning_rate: 0.0024
# 0:14:49.526524
# Epoch 1/25
# 44/44 [==============================] - 10s 75ms/step - loss: 0.0249 - val_loss: 8.5296e-04
# Epoch 2/25
# 44/44 [==============================] - 2s 50ms/step - loss: 9.4202e-04 - val_loss: 0.0050
# Epoch 3/25
# 44/44 [==============================] - 2s 49ms/step - loss: 8.6116e-04 - val_loss: 0.0013
# Epoch 4/25
# 44/44 [==============================] - 3s 60ms/step - loss: 6.3866e-04 - val_loss: 0.0018
# Epoch 5/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.3197e-04 - val_loss: 8.8577e-04
# Epoch 6/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.4960e-04 - val_loss: 0.0021
# Epoch 7/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.1840e-04 - val_loss: 0.0018
# Epoch 8/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.7137e-04 - val_loss: 5.4588e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.4255e-04 - val_loss: 6.1216e-04
# Epoch 10/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.3455e-04 - val_loss: 8.7936e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.2587e-04 - val_loss: 7.3932e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.5719e-04 - val_loss: 0.0046
# Epoch 13/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.8948e-04 - val_loss: 8.8158e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.0366e-04 - val_loss: 6.9848e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.5944e-04 - val_loss: 8.3509e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 57ms/step - loss: 3.8209e-04 - val_loss: 0.0016
# Epoch 17/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.1579e-04 - val_loss: 5.2722e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.1980e-04 - val_loss: 0.0018
# Epoch 19/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.1981e-04 - val_loss: 5.2722e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.0459e-04 - val_loss: 0.0012
# Epoch 21/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.3882e-04 - val_loss: 7.5055e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.6325e-04 - val_loss: 6.0201e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.5051e-04 - val_loss: 0.0023
# Epoch 24/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.8415e-04 - val_loss: 6.1490e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.8955e-04 - val_loss: 5.6864e-04
# 4/4 [==============================] - 1s 21ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  25
# Step 1. Number_of_prediction:  26  Average_MSE:  1.8642778058653957  Execution_time (s):  964.60183  Learning_rate: 0.0026
# 0:16:04.604081
# Epoch 1/25
# 44/44 [==============================] - 8s 68ms/step - loss: 0.0082 - val_loss: 0.0082
# Epoch 2/25
# 44/44 [==============================] - 2s 45ms/step - loss: 9.4895e-04 - val_loss: 0.0015
# Epoch 3/25
# 44/44 [==============================] - 2s 45ms/step - loss: 7.5744e-04 - val_loss: 6.3881e-04
# Epoch 4/25
# 44/44 [==============================] - 3s 58ms/step - loss: 6.6267e-04 - val_loss: 6.2144e-04
# Epoch 5/25
# 44/44 [==============================] - 2s 52ms/step - loss: 6.1511e-04 - val_loss: 9.0226e-04
# Epoch 6/25
# 44/44 [==============================] - 3s 59ms/step - loss: 6.0058e-04 - val_loss: 5.7035e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.6482e-04 - val_loss: 0.0033
# Epoch 8/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.1398e-04 - val_loss: 0.0018
# Epoch 9/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.8184e-04 - val_loss: 0.0019
# Epoch 10/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.5169e-04 - val_loss: 9.6234e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.3263e-04 - val_loss: 0.0015
# Epoch 12/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.5568e-04 - val_loss: 0.0025
# Epoch 13/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.7375e-04 - val_loss: 5.2957e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.5157e-04 - val_loss: 6.8718e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.2023e-04 - val_loss: 5.1164e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.9386e-04 - val_loss: 0.0015
# Epoch 17/25
# 44/44 [==============================] - 3s 59ms/step - loss: 3.4945e-04 - val_loss: 5.1441e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.2126e-04 - val_loss: 0.0018
# Epoch 19/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.4864e-04 - val_loss: 6.4814e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.7507e-04 - val_loss: 9.7314e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 59ms/step - loss: 3.5562e-04 - val_loss: 7.7654e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 59ms/step - loss: 3.8834e-04 - val_loss: 4.8795e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.0587e-04 - val_loss: 6.5224e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.0713e-04 - val_loss: 6.0748e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.3350e-04 - val_loss: 0.0010
# 4/4 [==============================] - 1s 22ms/step
# 53/53 [==============================] - 1s 23ms/step
# Prediction:  27
# Step 1. Number_of_prediction:  28  Average_MSE:  1.828202371646243  Execution_time (s):  1038.348497  Learning_rate: 0.0028
# 0:17:18.352718
# Epoch 1/25
# 44/44 [==============================] - 10s 72ms/step - loss: 0.0194 - val_loss: 0.0073
# Epoch 2/25
# 44/44 [==============================] - 2s 50ms/step - loss: 9.3529e-04 - val_loss: 0.0041
# Epoch 3/25
# 44/44 [==============================] - 2s 49ms/step - loss: 7.4068e-04 - val_loss: 0.0027
# Epoch 4/25
# 44/44 [==============================] - 2s 48ms/step - loss: 7.1805e-04 - val_loss: 0.0025
# Epoch 5/25
# 44/44 [==============================] - 2s 53ms/step - loss: 6.0462e-04 - val_loss: 5.5213e-04
# Epoch 6/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.7113e-04 - val_loss: 0.0010
# Epoch 7/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.1212e-04 - val_loss: 0.0014
# Epoch 8/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.0251e-04 - val_loss: 0.0011
# Epoch 9/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.3822e-04 - val_loss: 0.0012
# Epoch 10/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.3717e-04 - val_loss: 7.6246e-04
# Epoch 11/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.3568e-04 - val_loss: 8.9489e-04
# Epoch 12/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.3921e-04 - val_loss: 0.0050
# Epoch 13/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.1905e-04 - val_loss: 6.3443e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.2045e-04 - val_loss: 5.3065e-04
# Epoch 15/25
# 44/44 [==============================] - 2s 54ms/step - loss: 3.4435e-04 - val_loss: 5.2734e-04
# Epoch 16/25
# 44/44 [==============================] - 2s 54ms/step - loss: 3.9705e-04 - val_loss: 0.0020
# Epoch 17/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.1120e-04 - val_loss: 5.7566e-04
# Epoch 18/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.1435e-04 - val_loss: 0.0022
# Epoch 19/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.3311e-04 - val_loss: 6.0970e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 53ms/step - loss: 3.9218e-04 - val_loss: 0.0011
# Epoch 21/25
# 44/44 [==============================] - 2s 53ms/step - loss: 3.4362e-04 - val_loss: 6.7641e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 55ms/step - loss: 3.5783e-04 - val_loss: 5.3154e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.0119e-04 - val_loss: 0.0011
# Epoch 24/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.0398e-04 - val_loss: 4.9619e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.1794e-04 - val_loss: 8.1269e-04
# 4/4 [==============================] - 2s 20ms/step
# 53/53 [==============================] - 1s 22ms/step
# Prediction:  29
# Step 1. Number_of_prediction:  30  Average_MSE:  1.7856517916507058  Execution_time (s):  1109.758573  Learning_rate: 0.003
# 0:18:29.760618
# Epoch 1/25
# 44/44 [==============================] - 10s 81ms/step - loss: 0.0081 - val_loss: 0.0090
# Epoch 2/25
# 44/44 [==============================] - 2s 51ms/step - loss: 7.8394e-04 - val_loss: 0.0024
# Epoch 3/25
# 44/44 [==============================] - 2s 48ms/step - loss: 6.1493e-04 - val_loss: 9.4999e-04
# Epoch 4/25
# 44/44 [==============================] - 2s 50ms/step - loss: 6.6416e-04 - val_loss: 0.0017
# Epoch 5/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.1643e-04 - val_loss: 6.8104e-04
# Epoch 6/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.5850e-04 - val_loss: 6.7316e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.5479e-04 - val_loss: 0.0018
# Epoch 8/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.4459e-04 - val_loss: 0.0021
# Epoch 9/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.7949e-04 - val_loss: 0.0015
# Epoch 10/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.8096e-04 - val_loss: 0.0012
# Epoch 11/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.1483e-04 - val_loss: 5.4115e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.9016e-04 - val_loss: 0.0017
# Epoch 13/25
# 44/44 [==============================] - 3s 61ms/step - loss: 3.6876e-04 - val_loss: 5.1882e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.4472e-04 - val_loss: 5.8661e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.3559e-04 - val_loss: 6.7976e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.2334e-04 - val_loss: 0.0022
# Epoch 17/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.7833e-04 - val_loss: 8.1484e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.7171e-04 - val_loss: 8.4641e-04
# Epoch 19/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.2986e-04 - val_loss: 5.0523e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 58ms/step - loss: 5.5099e-04 - val_loss: 5.1876e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.9482e-04 - val_loss: 5.6401e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.9334e-04 - val_loss: 4.8323e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.5196e-04 - val_loss: 5.0165e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 69ms/step - loss: 4.1586e-04 - val_loss: 5.0539e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 66ms/step - loss: 3.6636e-04 - val_loss: 0.0014
# 4/4 [==============================] - 2s 21ms/step
# 53/53 [==============================] - 1s 22ms/step
# Prediction:  31
# Step 1. Number_of_prediction:  32  Average_MSE:  1.7801830596113226  Execution_time (s):  1186.322255  Learning_rate: 0.0032
# 0:19:46.322255
# Epoch 1/25
# 44/44 [==============================] - 9s 74ms/step - loss: 0.0083 - val_loss: 0.0021
# Epoch 2/25
# 44/44 [==============================] - 2s 48ms/step - loss: 8.3132e-04 - val_loss: 0.0012
# Epoch 3/25
# 44/44 [==============================] - 2s 46ms/step - loss: 5.5792e-04 - val_loss: 7.3255e-04
# Epoch 4/25
# 44/44 [==============================] - 2s 46ms/step - loss: 5.8351e-04 - val_loss: 6.5018e-04
# Epoch 5/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.6700e-04 - val_loss: 5.7405e-04
# Epoch 6/25
# 44/44 [==============================] - 2s 52ms/step - loss: 4.8326e-04 - val_loss: 6.4713e-04
# Epoch 7/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.0457e-04 - val_loss: 9.5867e-04
# Epoch 8/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.5712e-04 - val_loss: 7.2338e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.0484e-04 - val_loss: 0.0011
# Epoch 10/25
# 44/44 [==============================] - 3s 59ms/step - loss: 5.1293e-04 - val_loss: 0.0014
# Epoch 11/25
# 44/44 [==============================] - 3s 71ms/step - loss: 4.3021e-04 - val_loss: 6.0708e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 62ms/step - loss: 3.9605e-04 - val_loss: 0.0020
# Epoch 13/25
# 44/44 [==============================] - 3s 70ms/step - loss: 3.6462e-04 - val_loss: 5.2482e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 66ms/step - loss: 5.0393e-04 - val_loss: 5.2987e-04
# Epoch 15/25
# ...
# Epoch 16/25
# 44/44 [==============================] - 3s 68ms/step - loss: 4.1333e-04 - val_loss: 9.2737e-04
# Epoch 17/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.2356e-04 - val_loss: 6.8775e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.3259e-04 - val_loss: 0.0023
# Epoch 19/25
# 44/44 [==============================] - 3s 66ms/step - loss: 3.9386e-04 - val_loss: 5.1511e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 67ms/step - loss: 4.4093e-04 - val_loss: 5.4998e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 68ms/step - loss: 3.6749e-04 - val_loss: 7.0405e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 67ms/step - loss: 3.8242e-04 - val_loss: 6.4558e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.2727e-04 - val_loss: 0.0019
# Epoch 24/25
# 44/44 [==============================] - 3s 62ms/step - loss: 4.1966e-04 - val_loss: 6.2580e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.9342e-04 - val_loss: 5.1962e-04
# 4/4 [==============================] - 1s 22ms/step
# 53/53 [==============================] - 1s 22ms/step
# Prediction:  39
# Step 1. Number_of_prediction:  40  Average_MSE:  1.7300232033999585  Execution_time (s):  1487.604929  Learning_rate: 0.004
# 0:24:47.608623
# Epoch 1/25
# 44/44 [==============================] - 11s 102ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 2/25
# 44/44 [==============================] - 3s 74ms/step - loss: 8.9216e-04 - val_loss: 0.0017
# Epoch 3/25
# 44/44 [==============================] - 3s 59ms/step - loss: 6.7465e-04 - val_loss: 5.2443e-04
# Epoch 4/25
# 44/44 [==============================] - 2s 56ms/step - loss: 6.3026e-04 - val_loss: 6.6770e-04
# Epoch 5/25
# 44/44 [==============================] - 2s 52ms/step - loss: 5.3902e-04 - val_loss: 0.0015
# Epoch 6/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.8864e-04 - val_loss: 5.5440e-04
# Epoch 7/25
# 44/44 [==============================] - 2s 51ms/step - loss: 4.9355e-04 - val_loss: 6.5552e-04
# Epoch 8/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.7398e-04 - val_loss: 5.1393e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.6018e-04 - val_loss: 6.0254e-04
# Epoch 10/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.5143e-04 - val_loss: 0.0018
# Epoch 11/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.8022e-04 - val_loss: 0.0011
# Epoch 12/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.9076e-04 - val_loss: 0.0016
# Epoch 13/25
# 44/44 [==============================] - 3s 60ms/step - loss: 3.9815e-04 - val_loss: 5.0311e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.9242e-04 - val_loss: 5.2275e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 57ms/step - loss: 3.3682e-04 - val_loss: 5.2594e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 57ms/step - loss: 3.7250e-04 - val_loss: 0.0021
# Epoch 17/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.3851e-04 - val_loss: 4.9006e-04
# Epoch 18/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.7270e-04 - val_loss: 9.0241e-04
# Epoch 19/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.6778e-04 - val_loss: 4.7688e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 57ms/step - loss: 5.4744e-04 - val_loss: 6.1826e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.7016e-04 - val_loss: 0.0015
# Epoch 22/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.8877e-04 - val_loss: 0.0011
# Epoch 23/25
# 44/44 [==============================] - 3s 57ms/step - loss: 5.9120e-04 - val_loss: 6.2398e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.0876e-04 - val_loss: 6.0461e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 55ms/step - loss: 3.7350e-04 - val_loss: 0.0021
# 4/4 [==============================] - 1s 21ms/step
# 53/53 [==============================] - 1s 21ms/step
# Prediction:  41
# Step 1. Number_of_prediction:  42  Average_MSE:  1.7591850755518874  Execution_time (s):  1562.672339  Learning_rate: 0.004200000000000001
# 0:26:02.674518
# Epoch 1/25
# 44/44 [==============================] - 12s 133ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 2/25
# 44/44 [==============================] - 4s 80ms/step - loss: 8.1071e-04 - val_loss: 7.0973e-04
# Epoch 3/25
# 44/44 [==============================] - 3s 67ms/step - loss: 6.4134e-04 - val_loss: 0.0018
# Epoch 4/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.7062e-04 - val_loss: 6.2460e-04
# Epoch 5/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.5624e-04 - val_loss: 7.1222e-04
# Epoch 6/25
# 44/44 [==============================] - 3s 60ms/step - loss: 5.7767e-04 - val_loss: 0.0023
# Epoch 7/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.6187e-04 - val_loss: 0.0011
# Epoch 8/25
# 44/44 [==============================] - 3s 70ms/step - loss: 5.4003e-04 - val_loss: 5.7379e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 57ms/step - loss: 4.9162e-04 - val_loss: 5.4535e-04
# Epoch 10/25
# 44/44 [==============================] - 3s 64ms/step - loss: 6.4224e-04 - val_loss: 0.0013
# Epoch 11/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.5266e-04 - val_loss: 5.5989e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.9742e-04 - val_loss: 0.0029
# Epoch 13/25
# 44/44 [==============================] - 3s 63ms/step - loss: 5.8502e-04 - val_loss: 5.0864e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 65ms/step - loss: 4.7663e-04 - val_loss: 7.6109e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 64ms/step - loss: 3.4823e-04 - val_loss: 5.5858e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 63ms/step - loss: 3.7307e-04 - val_loss: 0.0010
# Epoch 17/25
# 44/44 [==============================] - 3s 65ms/step - loss: 3.8274e-04 - val_loss: 5.4370e-04
# Epoch 18/25
# 44/44 [==============================] - 3s 65ms/step - loss: 6.5745e-04 - val_loss: 0.0013
# Epoch 19/25
# 44/44 [==============================] - 3s 67ms/step - loss: 5.1925e-04 - val_loss: 5.0868e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 66ms/step - loss: 6.7169e-04 - val_loss: 4.8272e-04
# Epoch 21/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.8170e-04 - val_loss: 7.1403e-04
# Epoch 22/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.2557e-04 - val_loss: 0.0012
# Epoch 23/25
# 44/44 [==============================] - 3s 64ms/step - loss: 5.0208e-04 - val_loss: 4.9443e-04
# Epoch 24/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.3825e-04 - val_loss: 0.0013
# Epoch 25/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.0736e-04 - val_loss: 0.0025
# 4/4 [==============================] - 2s 23ms/step
# 53/53 [==============================] - 1s 24ms/step
# Prediction:  43
# Step 1. Number_of_prediction:  44  Average_MSE:  1.8143150415706157  Execution_time (s):  1648.21151  Learning_rate: 0.0044
# 0:27:28.213909
# Epoch 1/25
# 44/44 [==============================] - 12s 98ms/step - loss: 0.0581 - val_loss: 0.0080
# Epoch 2/25
# 44/44 [==============================] - 3s 60ms/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 3/25
# 44/44 [==============================] - 2s 51ms/step - loss: 6.9174e-04 - val_loss: 0.0048
# Epoch 4/25
# 44/44 [==============================] - 2s 52ms/step - loss: 6.4512e-04 - val_loss: 9.4518e-04
# Epoch 5/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.5439e-04 - val_loss: 9.1012e-04
# Epoch 6/25
# 44/44 [==============================] - 3s 67ms/step - loss: 5.3406e-04 - val_loss: 7.7109e-04
# Epoch 7/25
# 44/44 [==============================] - 2s 53ms/step - loss: 5.0863e-04 - val_loss: 0.0028
# Epoch 8/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.6452e-04 - val_loss: 5.3557e-04
# Epoch 9/25
# 44/44 [==============================] - 3s 61ms/step - loss: 5.1305e-04 - val_loss: 0.0025
# Epoch 10/25
# 44/44 [==============================] - 3s 64ms/step - loss: 4.4742e-04 - val_loss: 7.0047e-04
# Epoch 11/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.5227e-04 - val_loss: 7.0853e-04
# Epoch 12/25
# 44/44 [==============================] - 3s 59ms/step - loss: 4.4786e-04 - val_loss: 0.0028
# Epoch 13/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.3555e-04 - val_loss: 7.9819e-04
# Epoch 14/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.1897e-04 - val_loss: 5.2710e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 57ms/step - loss: 3.8285e-04 - val_loss: 5.3783e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.0169e-04 - val_loss: 8.7101e-04
# Epoch 17/25
# 44/44 [==============================] - 3s 60ms/step - loss: 4.8156e-04 - val_loss: 0.0013
# Epoch 18/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.7635e-04 - val_loss: 0.0014
# Epoch 19/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.0192e-04 - val_loss: 5.0040e-04
# Epoch 20/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.4045e-04 - val_loss: 0.0013
# Epoch 21/25
# 44/44 [==============================] - 3s 57ms/step - loss: 3.5733e-04 - val_loss: 0.0010
# Epoch 22/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.9253e-04 - val_loss: 4.8896e-04
# Epoch 23/25
# 44/44 [==============================] - 3s 73ms/step - loss: 4.0889e-04 - val_loss: 0.0010
# Epoch 24/25
# 44/44 [==============================] - 3s 63ms/step - loss: 4.6454e-04 - val_loss: 8.2644e-04
# Epoch 25/25
# 44/44 [==============================] - 3s 61ms/step - loss: 4.3840e-04 - val_loss: 5.4253e-04
# 4/4 [==============================] - 1s 19ms/step
# 53/53 [==============================] - 1s 20ms/step
# Prediction:  45
# Step 1. Number_of_prediction:  46  Average_MSE:  1.7776666083447286  Execution_time (s):  1726.905215  Learning_rate: 0.004600000000000001
# 0:28:46.910350
# Epoch 1/25
# 44/44 [==============================] - 9s 85ms/step - loss: 0.0420 - val_loss: 0.0206
# Epoch 2/25
# 44/44 [==============================] - 2s 56ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 3/25
# 44/44 [==============================] - 2s 49ms/step - loss: 8.2518e-04 - val_loss: 0.0014
# Epoch 4/25
# 44/44 [==============================] - 2s 51ms/step - loss: 5.9059e-04 - val_loss: 6.6867e-04
# Epoch 5/25
# 44/44 [==============================] - 2s 46ms/step - loss: 5.9613e-04 - val_loss: 0.0024
# Epoch 6/25
# 44/44 [==============================] - 2s 47ms/step - loss: 5.4783e-04 - val_loss: 7.2594e-04
# Epoch 7/25
# 44/44 [==============================] - 2s 50ms/step - loss: 4.7793e-04 - val_loss: 0.0021
# Epoch 8/25
# 44/44 [==============================] - 2s 51ms/step - loss: 5.1369e-04 - val_loss: 8.2224e-04
# Epoch 9/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.7651e-04 - val_loss: 0.0026
# Epoch 10/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.0060e-04 - val_loss: 0.0010
# Epoch 11/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.1156e-04 - val_loss: 8.0923e-04
# Epoch 12/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.0471e-04 - val_loss: 0.0046
# Epoch 13/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.4126e-04 - val_loss: 7.9229e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 53ms/step - loss: 4.0274e-04 - val_loss: 5.6903e-04
# Epoch 15/25
# 44/44 [==============================] - 2s 54ms/step - loss: 3.5824e-04 - val_loss: 6.5232e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 58ms/step - loss: 4.3176e-04 - val_loss: 0.0015
# Epoch 17/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.2430e-04 - val_loss: 0.0013
# Epoch 18/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.7688e-04 - val_loss: 0.0018
# Epoch 19/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.3394e-04 - val_loss: 8.5826e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.1870e-04 - val_loss: 0.0015
# Epoch 21/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.4479e-04 - val_loss: 9.4485e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 55ms/step - loss: 3.6619e-04 - val_loss: 5.0916e-04
# Epoch 23/25
# 44/44 [==============================] - 2s 54ms/step - loss: 3.9769e-04 - val_loss: 0.0018
# Epoch 24/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.3758e-04 - val_loss: 8.1046e-04
# Epoch 25/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.7983e-04 - val_loss: 0.0015
# 4/4 [==============================] - 1s 21ms/step
# 53/53 [==============================] - 1s 20ms/step
# Prediction:  47
# Step 1. Number_of_prediction:  48  Average_MSE:  1.7774003536596654  Execution_time (s):  1796.600871  Learning_rate: 0.0048000000000000004
# 0:29:56.603496
# Epoch 1/25
# 44/44 [==============================] - 9s 82ms/step - loss: 0.0078 - val_loss: 0.0049
# Epoch 2/25
# 44/44 [==============================] - 3s 61ms/step - loss: 8.5395e-04 - val_loss: 0.0015
# Epoch 3/25
# 44/44 [==============================] - 2s 49ms/step - loss: 5.7683e-04 - val_loss: 0.0014
# Epoch 4/25
# 44/44 [==============================] - 2s 48ms/step - loss: 5.6825e-04 - val_loss: 0.0017
# Epoch 5/25
# 44/44 [==============================] - 2s 46ms/step - loss: 5.1491e-04 - val_loss: 5.5713e-04
# Epoch 6/25
# 44/44 [==============================] - 2s 46ms/step - loss: 4.7003e-04 - val_loss: 0.0012
# Epoch 7/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.3181e-04 - val_loss: 0.0021
# Epoch 8/25
# 44/44 [==============================] - 2s 50ms/step - loss: 4.8571e-04 - val_loss: 0.0010
# Epoch 9/25
# 44/44 [==============================] - 2s 56ms/step - loss: 4.4290e-04 - val_loss: 5.1484e-04
# Epoch 10/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.6738e-04 - val_loss: 0.0013
# Epoch 11/25
# 44/44 [==============================] - 2s 54ms/step - loss: 4.4091e-04 - val_loss: 0.0011
# Epoch 12/25
# 44/44 [==============================] - 2s 53ms/step - loss: 6.0492e-04 - val_loss: 0.0030
# Epoch 13/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.6855e-04 - val_loss: 4.9024e-04
# Epoch 14/25
# 44/44 [==============================] - 2s 55ms/step - loss: 4.9450e-04 - val_loss: 5.2905e-04
# Epoch 15/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.4807e-04 - val_loss: 5.2244e-04
# Epoch 16/25
# 44/44 [==============================] - 3s 58ms/step - loss: 3.8718e-04 - val_loss: 7.3151e-04
# Epoch 17/25
# 44/44 [==============================] - 2s 56ms/step - loss: 3.8427e-04 - val_loss: 6.6180e-04
# Epoch 18/25
# 44/44 [==============================] - 2s 55ms/step - loss: 5.9976e-04 - val_loss: 0.0013
# Epoch 19/25
# 44/44 [==============================] - 2s 55ms/step - loss: 6.4475e-04 - val_loss: 5.2765e-04
# Epoch 20/25
# 44/44 [==============================] - 2s 54ms/step - loss: 7.6356e-04 - val_loss: 8.4090e-04
# Epoch 21/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.1358e-04 - val_loss: 4.5565e-04
# Epoch 22/25
# 44/44 [==============================] - 2s 54ms/step - loss: 5.5742e-04 - val_loss: 0.0014
# Epoch 23/25
# 44/44 [==============================] - 2s 56ms/step - loss: 5.1917e-04 - val_loss: 4.6535e-04
# Epoch 24/25
# 44/44 [==============================] - 2s 57ms/step - loss: 4.8650e-04 - val_loss: 0.0014
# Epoch 25/25
# 44/44 [==============================] - 2s 57ms/step - loss: 3.9015e-04 - val_loss: 0.0032
# 4/4 [==============================] - 1s 21ms/step
# 53/53 [==============================] - 1s 22ms/step
# Prediction:  49
# Step 1. Number_of_prediction:  50  Average_MSE:  1.8482837449959357  Execution_time (s):  1866.453571  Learning_rate: 0.005
# 0:31:06.454830
# Sending file...
# File sent successfully
